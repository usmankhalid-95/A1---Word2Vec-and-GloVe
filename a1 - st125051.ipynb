# %% [markdown]
# ## Model Comparison and Performance Analysis
#
# | **Model**                        | **Window Size** | **Training Loss** | **Training Time** | **Syntactic Accuracy** | **Semantic Accuracy** |
# |-----------------------------------|:---------------:|:-----------------:|:---------------------------:|:----------------------:|:---------------------:|
# | **Skipgram**                      |        2        |      7.804078     |           0.838465          |           0            |           0           |
# | **Skipgram (with negative sampling)** |        2        |      0.252254     |           0.915590          |           0            |           0           |
# | **GloVe**                         |        2        |      1.761795     |           0.163522          |           0            |           0           |
# | **GloVe (Gensim implementation)** |       NA        |         NA        |              NA             |         0.50           |         0.93          |

# %% [markdown]
# ## Correlation
#
# | **Model**            | **Skipgram** | **Skipgram negative** | **GloVe** | **GloVe gensim** |
# |----------------------|--------------|----------------------------------------|-----------|------------------------------------|
# | **Correlation**       |    0.064204  |     -0.05998                           |   0.05199 |            0.54308                |

# %%
import numpy as np
import time
import pickle
import torch
import torch.nn as nn
from collections import Counter
import nltk
from nltk.corpus import brown
import torch.optim as optim
from itertools import combinations_with_replacement
import math
import os
import pandas as pd
from scipy.stats import spearmanr
from gensim.test.utils import datapath
from gensim.models import KeyedVectors
from gensim.scripts.glove2word2vec import glove2word2vec
from nltk.corpus import gutenberg

# %%
# news_corpus = brown.sents()
# news_corpus = news_corpus[:1000]  # Take the first 1000 sentences
# news_corpus = [[word.lower() for word in sent] for sent in news_corpus]
# print(news_corpus[:5])

# Load only the "news" category sentences from the Brown corpus
news_corpus = brown.sents(categories='news')
# Limit to 10,000 sentences (or less, depending on your task)
news_corpus = news_corpus[:1000]
# news_corpus = news_corpus[:100000] #todo
# Preprocess: Convert all words to lowercase
news_corpus = [[word.lower() for word in sent] for sent in news_corpus]

print(news_corpus[:5])
# Out:
# [['the', 'fulton', 'county', 'grand', 'jury', 'said', 'friday', 'an', 'investigation', 'of', "atlanta's", 'recent', 'primary', 'election', 'produced', '``', 'no', 'evidence', "''", 'that', 'any', 'irregularities', 'took', 'place', '.'], ['the', 'jury', 'further', 'said', 'in', 'term-end', 'presentments', 'that', 'the', 'city', 'executive', 'committee', ',', 'which', 'had', 'over-all', 'charge', 'of', 'the', 'election', ',', '``', 'deserves', 'the', 'praise', 'and', 'thanks', 'of', 'the', 'city', 'of', 'atlanta', "''", 'for', 'the', 'manner', 'in', 'which', 'the', 'election', 'was', 'conducted', '.'], ['the', 'september-october', 'term', 'jury', 'had', 'been', 'charged', 'by', 'fulton', 'superior', 'court', 'judge', 'durwood', 'pye', 'to', 'investigate', 'reports', 'of', 'possible', '``', 'irregularities', "''", 'in', 'the', 'hard-fought', 'primary', 'which', 'was', 'won', 'by', 'mayor-nominate', 'ivan', 'allen', 'jr.', '.'], ['``', 'only', 'a', 'relative', 'handful', 'of', 'such', 'reports', 'was', 'received', "''", ',', 'the', 'jury', 'said', ',', '``', 'considering', 'the', 'widespread', 'interest', 'in', 'the', 'election', ',', 'the', 'number', 'of', 'voters', 'and', 'the', 'size', 'of', 'this', 'city', "''", '.'], ['the', 'jury', 'said', 'it', 'did', 'find', 'that', 'many', 'of', "georgia's", 'registration', 'and', 'election', 'laws', '``', 'are', 'outmoded', 'or', 'inadequate', 'and', 'often', 'ambiguous', "''", '.']]

# %%
#find unique words
flatten = lambda l: [item for sublist in l for item in sublist]
#assign unique integer
vocabs = list(set(flatten(news_corpus))) #all the words we have in the system - <UNK>

# %%
vocabs.append('<UNK>') #append unknown token to vocab

# %%
print(vocabs)
# Out:
# ['days', '58th', 'retirement', 'americans', 'countries', 'personal', 'crime', 'gursel', 'essential', 'described', 'feeling', "alliance's", 'enforcing', 'responsible', 'westfield', 'century', '61st', 'philosophy', 'assemblies', 'providence', 'lever', 'lines', 'following', 'again', 'amounts', 'quarrel', 'helping', 'twenty', 'activity', 'assistant', 'n.', 'contract-negotiation', 'spokesman', 'climate', 'conquer', 'rescind', 'validated', 'fees', 'depositors', 'information', 'imposed', 'given', 'stansbery', 'inject', 'seven-stories', 'decrease', 'wisdom', 'casualty', 'rival', 'griffin', '25', 'affirmation', 'hope', 'graft', 'whereby', 'owner', 'neil', 'man', 'sound', 'clerical', 'enactment', "country's", 'kika', '41', 'two-and-a-half-mile', 'essence', 'prove', 'active', 'destroy', 'raymondville', 'coming', 'retained', 'setting', 'allied', 'registered', 'byrd', 'nation', 'speech', 'latin', 'fbi', 'handled', 'up', 'fortin', '180', 'responding', 'dinner', 'redevelopment', 'chorus', 'born', 'composition', 'reaction', 'boyce', 'takes', 'chief', '$457,000', 'firms', 'monuments', '1.5', 'victories', 'inclination', 'parks', 'thanks', 'bush', 'criminal', 'believe', 'client', 'crump', 'signatures', 'protests', 'alternatives', '2', 'tangle', 'mayoral', 'letterman', 'deputy', 'contracted', 'formerly', 'widow', 'fighting', 'repeatedly', 'near', 'monthly', 'underdeveloped', 'strange', 'job-seekers', 'become', 'financed', 'as', 'contended', 'settle', 'cited', 'undermine', 'capitol', 'blended', 'conservation', 'gazing', 'delta', 'so-called', 'visits', 'placed', 'trade', 'a.m.', 'little', 'sharply', 'old', 'resources', 'teachers', 'work', 'southwestern', 'eight', 'entering', 'ankles', 'excess', 'seeks', 'questioned', 'after', 'worked', 'committee', 'real', 'modifications', 'copy', 'cd', 'amateurish', 'compensated', 'surrounded', 'movement', 'son', '29-5', 'adopted', 'violate', 'hospital-care', 'victim', 'solve', 'deny', 'advisers', '$43,000', 'areas', 'amending', "council's", 'source', 'federation', 'water', 'flies', 'senate', 'pointing', 'boun', 'lafayette', 'registration', 'formative', 'willing', 'hotels', 'surveyed', 'consolidated', 'intellectually', 'together', 'qualified', 'purchasing', 'lived', 'interesting', '$15,000', 'emergency', 'structure', "organization's", 'apparent', 'heart', '$740,000', 'harriman', 'achievement', 'making', 'cocktail', 'glad', 'douglas', 'tattered', '63', 'dismiss', 'parochial', '$1,000,000,000', 'adopt', 'seeking', 'brought', 'hughes', 'expense', "cotten's", 'co-operative', 'terms', 'bomb', 'nitroglycerine', 'headed', 'speeches', 'island', 'profound', 'socialist', 'original', 'payment', 'wayne', 'share', 'recipient', 'unchanged', 'h.', 'immediate', 'method', 'rising', 'okla.', 'build', '74', 'feb.', 'child', 'fortier', 'officers', 'wrongful', 'procedures', 'cod', 'headquarters', 'however', 'clearing', 'think', '$451,500', 'projects', 'unspecified', 'retired', 'scheduling', 'proposal', 'r-cape', 'aid-to-education', 'karol', 'democracy', 'been', 'whatever', 'monumental', 'sam', 'shops', 'more', 'way', 'njust', 'assembly', 'cities', 'matters', 'snodgrass', 'williams', 'voiced', '8', 'affected', 'fundamentalism', 'remarked', 'donations', "city's", 'parade', 'parimutuels', 'vacancy', '$37,500', 'foes', 'contention', 'settlement', 'violence', 'comes', 'carry', 'considerably', 'ask', '4', 'donald', 'canvassers', "kennedy's", 'd', 'weaver', 'strengthening', 'cross', 'flat', 'too', 'advice', 'biggest', 'dewey', 'selfish', 'mates', 'timely', 'observing', 'republic', 'customers', 'calls', 'center', 'startled', 'freedom', 'continuous', 'teaches', 'visiting', 'nevertheless', '$2', 'excise', 'usually', 'marching', '520-acre', 'met', 'fund-raising', 'need', 'combating', 'quickie', 'recommended', 'classes', 'designed', 'probably', 'abatuno', 'external', 'optimism', 'canal', 'doxiadis', 'connall', 'junta', 'pulled', 'justice', '36', 'visit', 'ride', 'k.', '$157,460', 'widespread', 'estimated', 'ban', 'small-town', 'used', 'yesterday' ...

# %%
len(vocabs)
# Out:
# 4273

# %%
#create handy mapping between integer and word
word2index = {v:idx for idx, v in enumerate(vocabs)}
word2index['traffic']
# Out:
# 1311

# %%
index2word = {v:k for k, v in word2index.items()}
index2word[10]
# Out:
# 'feeling'

# %%
print(f"Default number of threads: {torch.get_num_threads()}")
# Out:
# Default number of threads: 8

# %%
torch.set_num_threads(torch.get_num_threads()) 
device = torch.device('cpu')

# %%
torch.manual_seed(42)
voc_size   = len(vocabs)
emb_size = batch_size = window_size = 2

# %% [markdown]
# ## Word2Vec

# %% [markdown]
# ### 1. Prepare train data

# %%
#create pairs of center word, and outside word

def random_batch(batch_size, corpus, windows_size):

    skipgrams = []

    #loop each corpus
    for doc in corpus:
        #look from the 2nd word until second last word
        for i in range(windows_size, len(doc)-windows_size):
            #center word
            center = word2index[doc[i]]
            #outside words = 2 words
            outside = []
            for j in range(i-windows_size, i+windows_size+1):
                outside.append(word2index[doc[j]])
            #for each of these two outside words, we gonna append to a list
            for each_out in outside:
                skipgrams.append([center, each_out])
                #center, outside1;   center, outside2
                
    random_index = np.random.choice(range(len(skipgrams)), batch_size, replace=False)
    
    inputs, labels = [], []
    for index in random_index:
        inputs.append([skipgrams[index][0]])
        labels.append([skipgrams[index][1]])
        
    return np.array(inputs), np.array(labels)

# %% [markdown]
# ## Model

# %%
class Skipgram(nn.Module):
    
    def __init__(self, voc_size, emb_size):
        super(Skipgram, self).__init__()
        self.embedding_center  = nn.Embedding(voc_size, emb_size)
        self.embedding_outside = nn.Embedding(voc_size, emb_size)
    
    def forward(self, center, outside, all_vocabs):
        center_embedding     = self.embedding_center(center)  #(batch_size, 1, emb_size)
        outside_embedding    = self.embedding_center(outside) #(batch_size, 1, emb_size)
        all_vocabs_embedding = self.embedding_center(all_vocabs) #(batch_size, voc_size, emb_size)
        
        top_term = torch.exp(outside_embedding.bmm(center_embedding.transpose(1, 2)).squeeze(2))
        #batch_size, 1, emb_size) @ (batch_size, emb_size, 1) = (batch_size, 1, 1) = (batch_size, 1) 

        lower_term = all_vocabs_embedding.bmm(center_embedding.transpose(1, 2)).squeeze(2)
        #batch_size, voc_size, emb_size) @ (batch_size, emb_size, 1) = (batch_size, voc_size, 1) = (batch_size, voc_size) 
        
        lower_term_sum = torch.sum(torch.exp(lower_term), 1)  #(batch_size, 1)
        
        loss = -torch.mean(torch.log(top_term / lower_term_sum))  #scalar
        
        return loss

# %%
def prepare_sequence(seq, word2index):
    idxs = list(map(lambda w: word2index[w] if word2index.get(w) is not None else word2index["<UNK>"], seq))
    return torch.LongTensor(idxs)

# %%
#prepare all vocabs
all_vocabs = prepare_sequence(list(vocabs), word2index).expand(batch_size, voc_size).to(device)
all_vocabs
# Out:
# tensor([[   0,    1,    2,  ..., 4270, 4271, 4272],
#         [   0,    1,    2,  ..., 4270, 4271, 4272]])

# %%
skipgram_model  = Skipgram(voc_size, emb_size).to(device)
optimizer  = optim.Adam(skipgram_model.parameters(), lr=0.001)
# epochs = 10000 #todo
epochs = 10
start_time = time.time()

for epoch in range(epochs):
    #get batch
    input_batch, label_batch = random_batch(batch_size, news_corpus, window_size)
    input_tensor = torch.LongTensor(input_batch).to(device)
    label_tensor = torch.LongTensor(label_batch).to(device)
    
    #predict
    loss = skipgram_model(input_tensor, label_tensor, all_vocabs)
    
    #backprogate
    optimizer.zero_grad()
    loss.backward()
    
    #update alpha
    optimizer.step()
    
    #print the loss
    # if (epoch + 1) % 1000 == 0: #todo
    print(f"Epoch {epoch+1:6.0f}   |   Loss: {loss:2.6f}")

print(f"Train time: {time.time()-start_time}")
# Out:
# Epoch      1   |   Loss: 8.404066
# Epoch      2   |   Loss: 7.567184
# Epoch      3   |   Loss: 8.743052
# Epoch      4   |   Loss: 8.983487
# Epoch      5   |   Loss: 8.476640
# Epoch      6   |   Loss: 7.716052
# Epoch      7   |   Loss: 8.771048
# Epoch      8   |   Loss: 11.064310
# Epoch      9   |   Loss: 9.715869
# Epoch     10   |   Loss: 9.133204
# Train time: 0.8357000350952148

# %% [markdown]
# ## 3. Negative Sampling
#
# ### Unigram distribution
#
# $$P(w)=U(w)^{3/4}/Z$$

# %%
z = 0.001

# %%
#count
from collections import Counter

word_count = Counter(flatten(news_corpus))
word_count

#get the total number of words
num_total_words = sum([c for w, c in word_count.items()])
num_total_words
# Out:
# 22079

# %%
unigram_table = []

for v in vocabs:
    uw = word_count[v] / num_total_words
    uw_alpha = int((uw ** 0.75) / z)
    unigram_table.extend([v] * uw_alpha)

Counter(unigram_table)
# Out:
# Counter({'the': 137,
#          ',': 89,
#          '.': 87,
#          'of': 73,
#          'to': 62,
#          'a': 53,
#          'in': 52,
#          'and': 47,
#          'for': 36,
#          'that': 30,
#          '``': 29,
#          "''": 28,
#          'is': 26,
#          'he': 26,
#          'on': 25,
#          'said': 25,
#          'be': 24,
#          'by': 22,
#          'was': 22,
#          'would': 21,
#          'as': 19,
#          'it': 19,
#          'has': 17,
#          'will': 17,
#          'with': 17,
#          'his': 15,
#          'state': 15,
#          'at': 15,
#          'not': 14,
#          'this': 14,
#          'an': 14,
#          'been': 12,
#          'from': 12,
#          'which': 12,
#          'who': 12,
#          'but': 11,
#          'have': 11,
#          'are': 11,
#          '--': 11,
#          'more': 10,
#          'new': 10,
#          'president': 10,
#          'one': 10,
#          'city': 10,
#          'administration': 10,
#          'mr.': 10,
#          'they': 9,
#          'or': 9,
#          'some': 9,
#          'there': 9,
#          'had': 9,
#          'year': 9,
#          'committee': 8,
#          'other': 8,
#          'bill': 8,
#          'its': 8,
#          'last': 8,
#          'after': 7,
#          'government': 7,
#          'tax': 7,
#          'democratic': 7,
#          'also': 7,
#          'house': 7,
#          'county': 7,
#          'election': 7,
#          'plan': 7,
#          'states': 7,
#          'were': 7,
#          'no': 7,
#          'than': 7,
#          'out': 7,
#          'their': 7,
#          'up': 6,
#          'made': 6,
#          'first': 6,
#          'council': 6,
#          'program': 6,
#          'i': 6,
#          'united': 6,
#          'school': 6,
#          'party': 6,
#          'if': 6,
#          'we': 6,
#          'million': 6,
#          'home': 6,
#          'should': 6,
#          'two': 6,
#          'work': 5,
#          'hughes': 5,
#          'legislature': 5,
#          'over': 5,
#          'session': 5,
#          'aid': 5,
#          'such': 5,
#          '(': 5,
#          'jury': 5,
#          'special': 5,
#          'about': 5,
#          ')': 5,
#          'people': 5,
#          'when': 5,
#          'public': 5,
#          'department': 5,
#          'into': 5,
#          'court': 5,
#          'what': 5,
#          'board': 5,
#          'republican': 5,
#          'general': 5,
#          'take': 5,
#          'under': 5,
#          'years': 5,
#          ':': 5,
#          'vote': 5,
#          'must': 5,
#          'them': 5,
#          'can': 5,
#          'time': 5,
#          'could': 5,
#          'all': 5,
#          'district': 5,
#          'most': 5,
#          'expected': 5,
#          'schools': 5,
#          'these': 5,
#          'now': 5,
#          'federal': 5,
#          'texas': 5,
#          'kennedy': 5,
#          'senate': 4,
#          'director': 4,
#          'make': 4,
#          'any': 4,
#          'only': 4,
#          'candidate': 4,
#          'project': 4,
#          'funds': 4,
#          'campaign': 4,
#          'education': 4,
#          'monday': 4,
#          'did': 4,
#          'law': 4,
#          'against': 4,
#          'washington': 4,
#          'per': 4,
#          'since': 4,
#          'local': 4,
#          'told': 4,
#          'pay': 4,
#          'asked': 4,
#          'mayor': 4,
#          'may': 4,
#          'issue': 4,
#          'day': 4,
#          'meeting': 4,
#          'care': 4,
#          'called': 4,
#          'medical': 4,
#          "'": 4,
#          'sen.': 4,
#          'each': 4,
#          'fire': 4,
#          'laos': 4,
#          'where': 4,
#          'three': 4,
#          'night': 4,
#          'increase': 4,
#          'j.': 4,
#          'both': 4,
#          'being': 4,
#          'secretary': 4,
#          'members': 4,
#          'political': 4,
#          'national': 4,
#          'days': 3,
#          'countries': 3,
#          'fees': 3,
#          'given': 3,
#          'man': 3,
#          'proposal': 3,
#          'calls': 3,
#          'need': 3,
#          'yesterday': 3,
#          'come': 3,
#          'between': 3,
#          'get': 3,
#          'leaders': 3,
#          'candidates': 3,
#          'without': 3,
#          'dallas': 3,
#          'white': 3,
#          'proposed': 3,
#          'barnett': 3,
#          'grants': 3,
#          'possible': 3,
#          'during': 3,
#          'persons': 3,
#          'primary': 3,
#          'high': 3,
#          'legislators': 3,
#          'tuesday': 3,
#          'cost': 3,
#          '1961': 3,
#          'charter': 3,
#          'five': 3,
#          'defense': 3,
#          'far': 3,
#          'friday': 3,
#          'another': 3,
#          'military': 3,
#          'those': 3,
#          'so': 3,
#          'cent': 3,
#          'bond': 3,
#          'go': 3,
#          'our': 3,
#          'service': 3,
#          'hospital': 3,
#          'whether': 3,
#          'c.': 3,
#          'w.': 3,
#          'case': 3,
#          'many': 3,
#          'resolution': 3,
#          'wagner': 3,
#          'do': 3,
#          'while': 3,
#          'mitchell': 3,
#          'week': 3,
#          'because': 3,
#          '10': 3,
#          'added': 3,
#          'dr.': 3,
#          'rule': 3,
#          'association': 3,
#          'jones': 3,
#          '?': 3,
#          'reported': 3,
#          'chairman': 3,
#          'health': 3,
#          'nations': 3,
#          'sales': 3,
#          'davis': 3,
#          'here': 3,
#          'college': 3,
#          'efforts': 3,
#          'judge': 3,
#          'back': 3,
#          'months': 3,
#          'hawksley': 3,
#          'left': 3,
#          'several': 3,
#          'even': 3,
#          'attack': 3,
#          'communist': 3,
#          'fulton': 3,
#          'very': 3,
#          'congress': 3,
#          'attorney': 3,
#          'taken': 3,
#          'cases': 3,
#          'term': 3,
#          'future': 3,
#          'development': 3,
#          'republicans': 3,
#          'voters': 3,
#          'hotel': 3,
#          'report': 3,
#          'eisenhower': 3,
#          'former': 3,
#          'present': 3,
#          '1': 3,
#          'before': 3,
#          'today': 3,
#          'james': 3,
#          'sunday': 3,
#          'passed': 3,
#          'give': 3,
#          'a.': 3,
#          'system': 3,
#          ';': 3,
#          'see': 3,
#          'governor': 3,
#          'long': 3,
#          'problem': 3,
#          'through': 3,
#          'organization': 3,
#          'help': 3,
#          'provide': 3,
#          'providence': 2,
#          'following': 2,
#          'again': 2,
#          'assistant': 2,
#          'information': 2,
#          'chief': 2,
#          'become': 2,
#          'eight': 2,
#          'cd': 2,
#          'water': 2,
#          'willing': 2,
#          'brought': 2,
#          'socialist': 2,
#          'build': 2,
#          'however': 2,
#          'assembly': 2,
#          'ask': 2,
#          '4': 2,
#          'recommended': 2,
#          'american': 2,
#          'population': 2,
#          'past': 2,
#          'payroll': 2,
#          'meet': 2,
#          'decided': 2,
#          'austin': 2,
#          'same': 2,
#          'parties': 2,
#          'investigation': 2,
#          'religious': 2,
#          'town': 2,
#          'might': 2,
#          'point': 2,
#          'rural': 2,
#          'down': 2,
#          'reports': 2,
#          'private': 2,
#          'means': 2,
#          'among': 2,
#          'just': 2,
#          'gov.': 2,
#          'use': 2,
#          'gubernatorial': 2,
#          'opposition': 2,
#          'martinelli': 2,
#          'jersey': 2,
#          'track': 2,
#          'laws': 2,
#          'corps': 2,
#          'six': 2,
#          'william': 2,
#          'recent': 2,
#          'own': 2,
#          'hemphill': 2,
#          'four': 2,
#          'major': 2,
#          'place': 2,
#          'steps': 2,
#          'act': 2,
#          'announced': 2,
#          'prince': 2,
#          'communists': 2,
#          'stand': 2,
#          'office': 2,
#          'involved': 2,
#          'charge': 2,
#          'degree': 2,
#          'hearing': 2,
#          'received': 2,
#          'ward': 2,
#          'soviet': 2,
#          'charged': 2,
#          'taxes': 2,
#          'next': 2,
#          'executive': 2,
#          'took': 2,
#          'charles': 2,
#          'right': 2,
#          '13': 2,
#          'plans': 2,
#          'run': 2,
#          'enough': 2,
#          'changes': 2,
#          'my': 2,
#          'rep.': 2,
#          'police': 2,
#          'highway': 2,
#          'amount': 2,
#          'certain': 2,
#          'massachusetts': 2,
#          'superintendent': 2,
#          'full': 2,
#          'further': 2,
#          'forces': 2,
#          'apparently': 2,
#          'leader': 2,
#          'group': 2,
#          'central': 2,
#          'construction': 2,
#          'john': 2,
#          'november': 2,
#          'legislation': 2,
#          'adc': 2,
#          'civil': 2,
#          'upon': 2,
#          'number': 2,
#          'research': 2,
#          'division': 2,
#          'welfare': 2,
#          'like': 2,
#          'june': 2,
#          'address': 2,
#          'able': 2,
#          'along': 2,
#          'part': 2,
#          'commission': 2,
#          'nursing': 2,
#          'avenue': 2,
#          'costs': 2,
#          'social': 2,
#          'd.': 2,
#          'services': 2,
#          'evidence': 2,
#          'policies': 2,
#          'member': 2,
#          'find': 2,
#          'firm': 2,
#          'themselves': 2,
#          'trial': 2,
#          'commissioner': 2,
#          'e.': 2,
#          'half': 2,
#          'full-time': 2,
#          'agreed': 2,
#          'then': 2,
#          'bonds': 2,
#          'wexler': 2,
#          'relations': 2,
#          'toward': 2,
#          'statements': 2,
#          'much': 2,
#          'congressional': 2,
#          'well': 2,
#          'matter': 2,
#          'grant': 2,
#          'citizens': 2,
#          'problems': 2,
#          'similar': 2,
#          'groups': 2,
#          'annual': 2,
#          'you': 2,
#          'bills': 2,
#          'still': 2,
#          'grand': 2,
#          'counties': 2,
#          'scheduled': 2,
#          'east': 2,
#          'co.': 2,
#          'mrs.': 2,
#          'ballot': 2,
#          'say': 2,
#          'philadelphia': 2,
#          'jr.': 2,
#          'within': 2,
#          'leadership': 2,
#          'army': 2,
#          'richard': 2,
#          'company': 2,
#          'dollars': 2,
#          'b.': 2,
#          'receive': 2,
#          'martin': 2,
#          'study': 2,
#          'approved': 2,
#          'foreign': 2,
#          'paid': 2,
#          'business': 2,
#          'god': 2,
#          'him': 2,
#          'petitions': 2,
#          'labor': 2,
#          'off': 2,
#          'money': 2,
#          'statement': 2,
#          '18': 2,
#          'coalition': 2,
#          'recommendations': 2,
#          'worth': 2,
#          'economic': 2,
#          'authority': 2,
#          'm.': 2,
#          'form': 2,
#          'done': 2,
#          'f.': 2,
#          'battle': 2,
#          'r.': 2,
#          'security': 2,
#          'later': 2,
#          '24': 2,
#          'action': 2,
#          'church': 2,
#          'how': 2,
#          'union': 2,
#          'conference': 2,
#          'thursday': 2,
#          'children': 2,
#          'additional': 2,
#          'elected': 2,
#          'know': 2,
#          'fight': 2,
#          'university': 2,
#          'head': 2,
#          'clark': 2,
#          'question': 2,
#          'does': 2,
#          'community': 2,
#          'running': 2,
#          'nato': 2,
#          'came': 2,
#          'appointment': 2,
#          'buckley': 2,
#          'policy': 2,
#          'workers': 2,
#          'declared': 2,
#          'race': 2,
#          'karns': 2,
#          'early': 2,
#          'effort': 2,
#          'measure': 2,
#          'concern': 2,
#          'property': 2,
#          'deaf': 2,
#          'dental': 2,
#          'gen.': 2,
#          'retirement': 1,
#          'americans': 1,
#          'personal': 1,
#          'crime': 1,
#          'gursel': 1,
#          'essential': 1,
#          'responsible': 1,
#          'westfield': 1,
#          'assemblies': 1,
#          'lines': 1,
#          'sound': 1,
#          'coming': 1,
#          'speech': 1,
#          'latin': 1,
#          'dinner': 1,
#          'redevelopment': 1,
#          'reaction': 1,
#          'bush': 1,
#          'criminal': 1,
#          'signatures': 1,
#          '2': 1,
#          'capitol': 1,
#          'conservation': 1,
#          'placed': 1,
#          'little': 1,
#          'old': 1,
#          'entering': 1,
#          'real': 1,
#          'movement': 1,
#          'adopted': 1,
#          'areas': 1,
#          "council's": 1,
#          'source': 1,
#          'hotels': 1,
#          'together': 1,
#          'purchasing': 1,
#          "organization's": 1,
#          'apparent': 1,
#          'making': 1,
#          'expense': 1,
#          'headed': 1,
#          'island': 1,
#          'original': 1,
#          'payment': 1,
#          'wayne': 1,
#          'h.': 1,
#          'immediate': 1,
#          'feb.': 1,
#          'child': 1,
#          'procedures': 1,
#          'think': 1,
#          'projects': 1,
#          'unspecified': 1,
#          'retired': 1,
#          'sam': 1,
#          'way': 1,
#          'cities': 1,
#          'williams': 1,
#          '8': 1,
#          "city's": 1,
#          'parade': 1,
#          'carry': 1,
#          'too': 1,
#          'mates': 1,
#          'center': 1,
#          'nevertheless': 1,
#          'designed': 1,
#          'junta': 1,
#          'estimated': 1,
#          'sheriff': 1,
#          'aj': 1,
#          'replied': 1,
#          '11': 1,
#          'difficult': 1,
#          'press': 1,
#          'expects': 1,
#          'daniel': 1,
#          'juvenile': 1,
#          'hand': 1,
#          'incumbent': 1,
#          'confidence': 1,
#          'planning': 1,
#          'understanding': 1,
#          'permits': 1,
#          'going': 1,
#          'stores': 1,
#          '17': 1,
#          'clear': 1,
#          'churches': 1,
#          'preserve': 1,
#          'effect': 1,
#          'clearly': 1,
#          'certainly': 1,
#          'big': 1,
#          'kansas': 1,
#          'directed': 1,
#          'tract': 1,
#          'ago': 1,
#          'audience': 1,
#          'side': 1,
#          'replace': 1,
#          'berger': 1,
#          'choice': 1,
#          'l.': 1,
#          'order': 1,
#          'went': 1,
#          'congressmen': 1,
#          'boston': 1,
#          'conflict': 1,
#          'alliance': 1,
#          'rescue': 1,
#          'fund': 1,
#          'basic': 1,
#          'science': 1,
#          'eugene': 1,
#          'despite': 1,
#          'doctor': 1,
#          'notice': 1,
#          'served': 1,
#          'support': 1,
#          'set': 1,
#          'matching': 1,
#          'institute': 1,
#          'recommend': 1,
#          'oslo': 1,
#          'bank': 1,
#          'sheets': 1,
#          'ever': 1,
#          'joint': 1,
#          'grover': 1,
#          'shortly': 1,
#          'led': 1,
#          'pfaff': 1,
#          'event': 1,
#          'why': 1,
#          'raised': 1,
#          'nuclear': 1,
#          'voluntary': 1,
#          'keeping': 1,
#          'raymond': 1,
#          'available': 1,
#          '1959': 1,
#          'named': 1,
#          'free': 1,
#          'effective': 1,
#          'fort': 1,
#          '35': 1,
#          'carcass': 1,
#          'want': 1,
#          'dog': 1,
#          'millions': 1,
#          'morse': 1,
#          "didn't": 1,
#          'working': 1,
#          'increased': 1,
#          'presented': 1,
#          'bureau': 1,
#          '12': 1,
#          'facilities': 1,
#          'best': 1,
#          'votes': 1,
#          'message': 1,
#          'deal': 1,
#          'experience': 1,
#          'joe': 1,
#          'residents': 1,
#          'principal': 1,
#          'bronx': 1,
#          'pace': 1,
#          'name': 1,
#          'republicanism': 1,
#          'radio': 1,
#          'ones': 1,
#          'issues': 1,
#          'gladden': 1,
#          'estimates': 1,
#          'sent': 1,
#          'revolving': 1,
#          'decisions': 1,
#          'ways': 1,
#          'really': 1,
#          'solicitor': 1,
#          'level': 1,
#          '30': 1,
#          'wife': 1,
#          'agencies': 1,
#          'station': 1,
#          'el': 1,
#          'parkhouse': 1,
#          'small': 1,
#          'semester': 1,
#          'already': 1,
#          'kept': 1,
#          'situation': 1,
#          "mayor's": 1,
#          'historic': 1,
#          'supported': 1,
#          'bankers': 1,
#          'barber': 1,
#          'warning': 1,
#          'berlin': 1,
#          'operation': 1,
#          'petition': 1,
#          'opinion': 1,
#          'obtained': 1,
#          'sign': 1,
#          'firmer': 1,
#          'seats': 1,
#          'stage': 1,
#          'manner': 1,
#          'greater': 1,
#          'area': 1,
#          'teamsters': 1,
#          'approval': 1,
#          'thing': 1,
#          'jan.': 1,
#          'miss': 1,
#          'cotten': 1,
#          'voted': 1,
#          'pass': 1,
#          'allen': 1,
#          'investigate': 1,
#          'commented': 1,
#          'licenses': 1,
#          'candidacy': 1,
#          'traffic': 1,
#          'railroad': 1,
#          'highly': 1,
#          'assistance': 1,
#          'merely': 1,
#          'prevent': 1,
#          'sue': 1,
#          'hear': 1,
#          'senators': 1,
#          'direction': 1,
#          '200': 1,
#          'rate': 1,
#          'vandiver': 1,
#          'raises': 1,
#          "governor's": 1,
#          'points': 1,
#          'air': 1,
#          'polls': 1,
#          'date': 1,
#          'companies': 1,
#          'international': 1,
#          'u.': 1,
#          'gop': 1,
#          'rhode': 1,
#          'ratcliff': 1,
#          'aged': 1,
#          'telephone': 1,
#          'pro-western': 1,
#          'personnel': 1,
#          'higher': 1,
#          'trucks': 1,
#          'goodis': 1,
#          "year's": 1,
#          'got': 1,
#          'voting': 1,
#          'oklahoma': 1,
#          'detailed': 1,
#          'issued': 1,
#          'oppose': 1,
#          'listed': 1,
#          'interested': 1,
#          '3': 1,
#          '1910': 1,
#          'nov.': 1,
#          'family': 1,
#          'land': 1,
#          'termed': 1,
#          'missionary': 1,
#          'life': 1,
#          'crisis': 1,
#          'sheeran': 1,
#          'leading': 1,
#          'opposed': 1,
#          'view': 1,
#          'heard': 1,
#          'hours': 1,
#          'bid': 1,
#          'populous': 1,
#          'premier': 1,
#          'hartsfield': 1,
#          'married': 1,
#          'reduce': 1,
#          'ahead': 1,
#          'offenses': 1,
#          'feel': 1,
#          "georgia's": 1,
#          'begin': 1,
#          'howard': 1,
#          'explosion': 1,
#          'held': 1,
#          'better': 1,
#          'suggested': 1,
#          'scholarships': 1,
#          'earlier': 1,
#          'goldberg': 1,
#          'billion': 1,
#          'africa': 1,
#          'test': 1,
#          'unity': 1,
#          'likely': 1,
#          'ticket': 1,
#          'precinct': 1,
#          'found': 1,
#          'p.m.': 1,
#          'necessary': 1,
#          'tell': 1,
#          'actually': 1,
#          'mention': 1,
#          'disclosed': 1,
#          'discrimination': 1,
#          'predict': 1,
#          '23d': 1,
#          'hardly': 1,
#          'nixon': 1,
#          'suit': 1,
#          'transition': 1,
#          'pathet': 1,
#          'speaker': 1,
#          'sessions': 1,
#          'prices': 1,
#          'taking': 1,
#          'zimmerman': 1,
#          'official': 1,
#          'lao': 1,
#          'us': 1,
#          'kind': 1,
#          'underlying': 1,
#          'democrats': 1,
#          'establishment': 1,
#          'generally': 1,
#          'patient': 1,
#          'defendants': 1,
#          '65': 1,
#          'favor': 1,
#          'believes': 1,
#          'using': 1,
#          'irregularities': 1,
#          'required': 1,
#          'tomorrow': 1,
#          'purchase': 1,
#          'amendment': 1,
#          'bellows': 1,
#          'something': 1,
#          'cannot': 1,
#          'period': 1,
#          'fee': 1,
#          'ranged': 1,
#          'elections': 1,
#          'asia': 1,
#          'reforms': 1,
#          'critical': 1,
#          'car': 1,
#          'saw': 1,
#          'banks': 1,
#          'subject': 1,
#          'until': 1,
#          'victory': 1,
#          'whom': 1,
#          'reama': 1,
#          'good': 1,
#          'lives': 1,
#          'according': 1,
#          'spent': 1,
#          'barnard': 1,
#          'delinquency': 1,
#          'put': 1,
#          '100': 1,
#          'concerned': 1,
#          'studied': 1,
#          'formula': 1,
#          'phouma': 1,
#          'politicians': 1,
#          'courses': 1,
#          'pennsylvania': 1,
#          'hold': 1,
#          'controversy': 1,
#          'builders': 1,
#          'southeast': 1,
#          'revenue': 1,
#          'everything': 1,
#          'open': 1,
#          'position': 1,
#          'faced': 1,
#          'ptc': 1,
#          'georgia': 1,
#          'roberts': 1,
#          'sponsored': 1,
#          'remark': 1,
#          'legislative': 1,
#          'george': 1,
#          'either': 1,
#          'offer': 1,
#          'cuba': 1,
#          'job': 1,
#          'pointed': 1,
#          'jackson': 1,
#          'accept': 1,
#          'face': 1,
#          'mean': 1,
#          'de': 1,
#          'senator': 1,
#          'paying': 1,
#          'record': 1,
#          "nation's": 1,
#          'paris': 1,
#          'alternative': 1,
#          'homes': 1,
#          'provides': 1,
#          'poll': 1,
#          'warden': 1,
#          'prison': 1,
#          'revenues': 1,
#          'third': 1,
#          'bourcier': 1,
#          'less': 1,
#          'anonymous': 1,
#          'scott': 1,
#          'beame': 1,
#          'officials': 1,
#          'opportunity': 1,
#          'soon': 1,
#          'defeated': 1,
#          'p.': 1,
#          'front': 1,
#          'parsons': 1,
#          'alone': 1,
#          'esplanade': 1,
#          'filed': 1,
#          'me': 1,
#          'war': 1,
#          'others': 1,
#          'great': 1,
#          'affairs': 1,
#          'important': 1,
#          'advisory': 1,
#          'causes': 1,
#          'attended': 1,
#          'practices': 1,
#          'involving': 1,
#          'limited': 1,
#          'basis': 1,
#          'seemed': 1,
#          'frank': 1,
#          'young': 1,
#          'turned': 1,
#          'requirement': 1,
#          'minister': 1,
#          'staff': 1,
#          'judges': 1,
#          'growth': 1,
#          'junior': 1,
#          'building': 1,
#          'maximum': 1,
#          'cooperation': 1,
#          "president's": 1,
#          'employed': 1,
#          'trenton': 1,
#          'buildings': 1,
#          'move': 1,
#          'denied': 1,
#          'square': 1,
#          'daughter': 1,
#          'delegates': 1,
#          'january': 1,
#          'finance': 1,
#          'interest': 1,
#          'housing': 1,
#          'felt': 1,
#          'allowed': 1,
#          'never': 1,
#          'vital': 1,
#          'informed': 1,
#          ...})

# %% [markdown]
# ## Model

# %%
import random

def negative_sampling(targets, unigram_table, k):
    batch_size = targets.shape[0]
    neg_samples = []
    for i in range(batch_size):  #(1, k)
        target_index = targets[i].item()
        nsample      = []
        while (len(nsample) < k):
            neg = random.choice(unigram_table)
            if word2index[neg] == target_index:
                continue
            nsample.append(neg)
        neg_samples.append(prepare_sequence(nsample, word2index).reshape(1, -1))
        
    return torch.cat(neg_samples) #batch_size, k

# %% [markdown]
# $$\mathbf{J}_{\text{neg-sample}}(\mathbf{v}_c,o,\mathbf{U})=-\log(\sigma(\mathbf{u}_o^T\mathbf{v}_c))-\sum_{k=1}^K\log(\sigma(-\mathbf{u}_k^T\mathbf{v}_c))$$

# %%
class SkipgramNegSampling(nn.Module):
    
    def __init__(self, voc_size, emb_size):
        super(SkipgramNegSampling, self).__init__()
        self.embedding_center  = nn.Embedding(voc_size, emb_size)
        self.embedding_outside = nn.Embedding(voc_size, emb_size)
        self.logsigmoid        = nn.LogSigmoid()
    
    def forward(self, center, outside, negative):
        #center, outside:  (bs, 1)
        #negative       :  (bs, k)
        
        center_embed   = self.embedding_center(center) #(bs, 1, emb_size)
        outside_embed  = self.embedding_outside(outside) #(bs, 1, emb_size)
        negative_embed = self.embedding_outside(negative) #(bs, k, emb_size)
        
        uovc           = outside_embed.bmm(center_embed.transpose(1, 2)).squeeze(2) #(bs, 1)
        ukvc           = -negative_embed.bmm(center_embed.transpose(1, 2)).squeeze(2) #(bs, k)
        ukvc_sum       = torch.sum(ukvc, 1).reshape(-1, 1) #(bs, 1)
        
        loss           = self.logsigmoid(uovc) + self.logsigmoid(ukvc_sum)
        
        return -torch.mean(loss)

# %% [markdown]
# ### 3. Training

# %%
skipgram_neg_model   = SkipgramNegSampling(voc_size, emb_size).to(device)
optimizer  = optim.Adam(skipgram_neg_model.parameters(), lr=0.001)
# epochs = 10000 #todo
epochs = 10
k = 5
start_time = time.time()

for epoch in range(epochs):
    
    #get batch
    input_batch, label_batch = random_batch(batch_size, news_corpus, window_size)
    input_tensor = torch.LongTensor(input_batch).to(device)
    label_tensor = torch.LongTensor(label_batch).to(device)
    
    #predict
    neg_samples = negative_sampling(label_tensor, unigram_table, k).to(device)
    loss = skipgram_neg_model(input_tensor, label_tensor, neg_samples)
    
    #backprogate
    optimizer.zero_grad()
    loss.backward()
    
    #update alpha
    optimizer.step()
    
    #print the loss
    # if (epoch + 1) % 1000 == 0: #todo
    print(f"Epoch {epoch+1:6.0f} | Loss: {loss:2.6f}")

print(f"Training time: {time.time()-start_time}")
# Out:
# Epoch      1 | Loss: 1.673046
# Epoch      2 | Loss: 2.207402
# Epoch      3 | Loss: 1.561828
# Epoch      4 | Loss: 1.078969
# Epoch      5 | Loss: 1.582053
# Epoch      6 | Loss: 1.544562
# Epoch      7 | Loss: 1.131451
# Epoch      8 | Loss: 1.624706
# Epoch      9 | Loss: 3.207410
# Epoch     10 | Loss: 1.909121
# Training time: 0.7606899738311768

# %% [markdown]
# ## 2. Build Co-occurence Matrix X

# %% [markdown]
# Here, we need to count the co-occurence of two words given some window size.  We gonna use window size of 2.

# %%
X_i = Counter(flatten(news_corpus))
X_i
# Out:
# Counter({'the': 1569,
#          ',': 878,
#          '.': 857,
#          'of': 676,
#          'to': 549,
#          'a': 440,
#          'in': 438,
#          'and': 377,
#          'for': 266,
#          'that': 211,
#          '``': 202,
#          "''": 191,
#          'he': 176,
#          'is': 171,
#          'on': 165,
#          'said': 164,
#          'be': 153,
#          'by': 143,
#          'was': 138,
#          'would': 131,
#          'it': 119,
#          'as': 114,
#          'with': 102,
#          'has': 100,
#          'will': 97,
#          'his': 89,
#          'at': 84,
#          'state': 82,
#          'an': 81,
#          'not': 78,
#          'this': 75,
#          'been': 66,
#          'which': 65,
#          'from': 65,
#          'who': 61,
#          'are': 58,
#          'have': 58,
#          '--': 58,
#          'but': 57,
#          'city': 54,
#          'more': 52,
#          'mr.': 52,
#          'administration': 50,
#          'one': 48,
#          'new': 48,
#          'president': 48,
#          'they': 46,
#          'had': 45,
#          'or': 45,
#          'there': 45,
#          'some': 43,
#          'year': 43,
#          'its': 40,
#          'committee': 39,
#          'last': 39,
#          'bill': 38,
#          'other': 37,
#          'county': 35,
#          'no': 35,
#          'after': 35,
#          'house': 35,
#          'their': 35,
#          'states': 35,
#          'election': 34,
#          'than': 34,
#          'were': 34,
#          'out': 33,
#          'plan': 31,
#          'tax': 31,
#          'also': 30,
#          'democratic': 30,
#          'government': 30,
#          'should': 29,
#          'first': 29,
#          'united': 29,
#          'two': 28,
#          'program': 28,
#          'we': 28,
#          'party': 28,
#          'up': 28,
#          'i': 28,
#          'council': 27,
#          'million': 27,
#          'made': 26,
#          'school': 26,
#          'if': 26,
#          'home': 25,
#          'all': 24,
#          'jury': 23,
#          'these': 23,
#          'federal': 23,
#          'general': 23,
#          'under': 23,
#          'work': 23,
#          'texas': 23,
#          'public': 23,
#          'years': 23,
#          'could': 23,
#          'court': 22,
#          'them': 22,
#          'department': 22,
#          '(': 22,
#          ')': 22,
#          'can': 22,
#          'over': 22,
#          'schools': 22,
#          'republican': 22,
#          'when': 21,
#          ':': 21,
#          'must': 21,
#          'time': 21,
#          'session': 21,
#          'now': 21,
#          'hughes': 21,
#          'such': 20,
#          'take': 20,
#          'vote': 20,
#          'expected': 20,
#          'what': 20,
#          'board': 20,
#          'people': 20,
#          'district': 20,
#          'legislature': 19,
#          'into': 19,
#          'most': 19,
#          'about': 19,
#          'aid': 19,
#          'special': 19,
#          'kennedy': 19,
#          'law': 18,
#          'night': 18,
#          'each': 18,
#          'three': 18,
#          'pay': 18,
#          'local': 18,
#          "'": 18,
#          'national': 18,
#          'any': 17,
#          'only': 17,
#          'since': 17,
#          'meeting': 17,
#          'make': 17,
#          'monday': 17,
#          'issue': 17,
#          'against': 17,
#          'members': 17,
#          'did': 16,
#          'both': 16,
#          'funds': 16,
#          'may': 16,
#          'fire': 16,
#          'political': 16,
#          'sen.': 16,
#          'per': 16,
#          'director': 16,
#          'where': 16,
#          'increase': 16,
#          'medical': 15,
#          'mayor': 15,
#          'j.': 15,
#          'candidate': 15,
#          'asked': 15,
#          'campaign': 15,
#          'senate': 15,
#          'being': 15,
#          'told': 15,
#          'day': 15,
#          'education': 15,
#          'washington': 15,
#          'project': 15,
#          'called': 15,
#          'secretary': 15,
#          'care': 15,
#          'laos': 15,
#          'fulton': 14,
#          'primary': 14,
#          'back': 14,
#          'republicans': 14,
#          'before': 14,
#          'go': 14,
#          'sales': 14,
#          'resolution': 14,
#          'sunday': 14,
#          'persons': 14,
#          'between': 14,
#          'get': 14,
#          '?': 14,
#          'those': 14,
#          'military': 14,
#          ';': 14,
#          'leaders': 14,
#          '1': 13,
#          'added': 13,
#          'man': 13,
#          'chairman': 13,
#          'governor': 13,
#          'days': 13,
#          'jones': 13,
#          'dallas': 13,
#          'proposal': 13,
#          'a.': 13,
#          'yesterday': 13,
#          'case': 13,
#          'countries': 13,
#          'mitchell': 13,
#          'proposed': 12,
#          'problem': 12,
#          'provide': 12,
#          'our': 12,
#          'health': 12,
#          'attorney': 12,
#          'tuesday': 12,
#          'james': 12,
#          'give': 12,
#          'week': 12,
#          'another': 12,
#          'without': 12,
#          'need': 12,
#          'reported': 12,
#          'high': 12,
#          'college': 12,
#          'dr.': 12,
#          'cases': 12,
#          'defense': 12,
#          'grants': 12,
#          'come': 12,
#          'communist': 12,
#          'wagner': 12,
#          'judge': 11,
#          'legislators': 11,
#          'cost': 11,
#          'through': 11,
#          'future': 11,
#          'do': 11,
#          'fees': 11,
#          'association': 11,
#          'hospital': 11,
#          'present': 11,
#          'given': 11,
#          'passed': 11,
#          'see': 11,
#          'former': 11,
#          'help': 11,
#          'report': 11,
#          'because': 11,
#          'several': 11,
#          'here': 11,
#          'c.': 11,
#          'even': 11,
#          'rule': 11,
#          'months': 11,
#          'eisenhower': 11,
#          'nations': 11,
#          'charter': 11,
#          'friday': 10,
#          'term': 10,
#          'possible': 10,
#          'voters': 10,
#          'many': 10,
#          'so': 10,
#          'w.': 10,
#          'whether': 10,
#          'taken': 10,
#          'five': 10,
#          'cent': 10,
#          'candidates': 10,
#          'system': 10,
#          '1961': 10,
#          'bond': 10,
#          'very': 10,
#          'while': 10,
#          'congress': 10,
#          'long': 10,
#          'davis': 10,
#          'calls': 10,
#          'during': 10,
#          'left': 10,
#          'development': 10,
#          'attack': 10,
#          '10': 10,
#          'today': 10,
#          'white': 10,
#          'service': 10,
#          'organization': 10,
#          'efforts': 10,
#          'far': 10,
#          'hawksley': 10,
#          'hotel': 10,
#          'barnett': 10,
#          'jr.': 9,
#          'received': 9,
#          'might': 9,
#          'citizens': 9,
#          'four': 9,
#          'office': 9,
#          'agreed': 9,
#          'relations': 9,
#          'bonds': 9,
#          'then': 9,
#          'plans': 9,
#          '18': 9,
#          'dollars': 9,
#          'means': 9,
#          'you': 9,
#          'amount': 9,
#          'question': 9,
#          'bills': 9,
#          'group': 9,
#          'martin': 9,
#          'involved': 9,
#          'social': 9,
#          'build': 9,
#          'use': 9,
#          'part': 9,
#          'along': 9,
#          'leader': 9,
#          'foreign': 9,
#          'leadership': 9,
#          'stand': 9,
#          'conference': 9,
#          'town': 9,
#          'further': 8,
#          'number': 8,
#          'laws': 8,
#          'well': 8,
#          'next': 8,
#          'services': 8,
#          'major': 8,
#          'counties': 8,
#          'elected': 8,
#          'police': 8,
#          'william': 8,
#          'mrs.': 8,
#          'm.': 8,
#          'property': 8,
#          'john': 8,
#          'highway': 8,
#          'gov.': 8,
#          'become': 8,
#          'construction': 8,
#          'authority': 8,
#          'rep.': 8,
#          'd.': 8,
#          'research': 8,
#          'done': 8,
#          'past': 8,
#          'does': 8,
#          'church': 8,
#          'scheduled': 8,
#          'down': 8,
#          'opposition': 8,
#          'children': 8,
#          'r.': 8,
#          'own': 8,
#          'annual': 8,
#          'right': 8,
#          'chief': 8,
#          'effort': 8,
#          'statements': 8,
#          'corps': 8,
#          'adc': 8,
#          'co.': 8,
#          'eight': 8,
#          'meet': 8,
#          'statement': 8,
#          'full': 8,
#          'policy': 8,
#          'soviet': 8,
#          'union': 8,
#          'within': 8,
#          'economic': 8,
#          'forces': 8,
#          'early': 8,
#          'central': 8,
#          'commissioner': 8,
#          'company': 8,
#          'hemphill': 8,
#          'grand': 7,
#          'investigation': 7,
#          'recent': 7,
#          'executive': 7,
#          'among': 7,
#          'policies': 7,
#          'welfare': 7,
#          'costs': 7,
#          'additional': 7,
#          'b.': 7,
#          'upon': 7,
#          'e.': 7,
#          '13': 7,
#          'race': 7,
#          'petitions': 7,
#          'approved': 7,
#          'study': 7,
#          'rural': 7,
#          'toward': 7,
#          'apparently': 7,
#          'paid': 7,
#          'battle': 7,
#          'similar': 7,
#          'like': 7,
#          'him': 7,
#          'just': 7,
#          'austin': 7,
#          'thursday': 7,
#          'fight': 7,
#          'charles': 7,
#          'enough': 7,
#          'population': 7,
#          'later': 7,
#          'taxes': 7,
#          'commission': 7,
#          'information': 7,
#          'water': 7,
#          '24': 7,
#          'massachusetts': 7,
#          'problems': 7,
#          'six': 7,
#          'themselves': 7,
#          'business': 7,
#          'american': 7,
#          'much': 7,
#          'karns': 7,
#          'matter': 7,
#          'ward': 7,
#          'east': 7,
#          'security': 7,
#          'how': 7,
#          'changes': 7,
#          'nato': 7,
#          'track': 7,
#          'came': 7,
#          'richard': 7,
#          'coalition': 7,
#          'half': 7,
#          'labor': 7,
#          'civil': 7,
#          'cd': 7,
#          'religious': 7,
#          'concern': 7,
#          'parties': 7,
#          'member': 7,
#          'martinelli': 7,
#          'division': 7,
#          'avenue': 7,
#          'evidence': 6,
#          'took': 6,
#          'place': 6,
#          'charge': 6,
#          'charged': 6,
#          'reports': 6,
#          'find': 6,
#          'recommended': 6,
#          'act': 6,
#          'however': 6,
#          'steps': 6,
#          'money': 6,
#          'receive': 6,
#          'appointment': 6,
#          'recommendations': 6,
#          'ask': 6,
#          'legislation': 6,
#          'announced': 6,
#          'run': 6,
#          'brought': 6,
#          'ballot': 6,
#          'assistant': 6,
#          'gubernatorial': 6,
#          'head': 6,
#          'worth': 6,
#          'off': 6,
#          'action': 6,
#          'november': 6,
#          'congressional': 6,
#          'superintendent': 6,
#          'certain': 6,
#          'measure': 6,
#          'hearing': 6,
#          'declared': 6,
#          'deaf': 6,
#          'still': 6,
#          'willing': 6,
#          'my': 6,
#          'decided': 6,
#          '4': 6,
#          'f.': 6,
#          'degree': 6,
#          'clark': 6,
#          'university': 6,
#          'army': 6,
#          'firm': 6,
#          'community': 6,
#          'able': 6,
#          'trial': 6,
#          'grant': 6,
#          'address': 6,
#          'say': 6,
#          'wexler': 6,
#          'workers': 6,
#          'dental': 6,
#          'payroll': 6,
#          'nursing': 6,
#          'following': 6,
#          'assembly': 6,
#          'again': 6,
#          'communists': 6,
#          'groups': 6,
#          'prince': 6,
#          'providence': 6,
#          'full-time': 6,
#          'know': 6,
#          'point': 6,
#          'form': 6,
#          'gen.': 6,
#          'socialist': 6,
#          'running': 6,
#          'jersey': 6,
#          'private': 6,
#          'same': 6,
#          'buckley': 6,
#          'june': 6,
#          'philadelphia': 6,
#          'god': 6,
#          'atlanta': 5,
#          'studied': 5,
#          'follow': 5,
#          'generally': 5,
#          'believes': 5,
#          'greater': 5,
#          'urged': 5,
#          'enabling': 5,
#          'effect': 5,
#          '2': 5,
#          'officials': 5,
#          'pass': 5,
#          'hartsfield': 5,
#          'williams': 5,
#          'petition': 5,
#          'listed': 5,
#          "mayor's": 5,
#          'age': 5,
#          'together': 5,
#          'pelham': 5,
#          'l.': 5,
#          'gop': 5,
#          'held': 5,
#          'blue': 5,
#          'voting': 5,
#          'signatures': 5,
#          'despite': 5,
#          'making': 5,
#          'hold': 5,
#          'test': 5,
#          'source': 5,
#          'roads': 5,
#          'every': 5,
#          'seek': 5,
#          'set': 5,
#          'something': 5,
#          'opposed': 5,
#          'support': 5,
#          'teacher': 5,
#          'got': 5,
#          'order': 5,
#          'himself': 5,
#          'march': 5,
#          'post': 5,
#          'too': 5,
#          'soon': 5,
#          'carry': 5,
#          'led': 5,
#          'rules': 5,
#          'companies': 5,
#          'parkhouse': 5,
#          'attend': 5,
#          'el': 5,
#          'tell': 5,
#          'better': 5,
#          'heard': 5,
#          'districts': 5,
#          'third': 5,
#          'instead': 5,
#          'fee': 5,
#          'license': 5,
#          '3': 5,
#          'taking': 5,
#          'kind': 5,
#          'affairs': 5,
#          'senator': 5,
#          'west': 5,
#          'proposals': 5,
#          'needs': 5,
#          'large': 5,
#          'spent': 5,
#          'de': 5,
#          'teaching': 5,
#          'person': 5,
#          'island': 5,
#          'served': 5,
#          'limited': 5,
#          'defendants': 5,
#          'bellows': 5,
#          'indicated': 5,
#          'mean': 5,
#          'working': 5,
#          'way': 5,
#          'press': 5,
#          'precinct': 5,
#          'aged': 5,
#          'capitol': 5,
#          'higher': 5,
#          'patient': 5,
#          'formula': 5,
#          'needed': 5,
#          'young': 5,
#          'going': 5,
#          'matching': 5,
#          'lines': 5,
#          'housing': 5,
#          'presidential': 5,
#          'immediate': 5,
#          'oslo': 5,
#          'step': 5,
#          'attempt': 5,
#          'weeks': 5,
#          'ago': 5,
#          'geneva': 5,
#          'prevent': 5,
#          'lao': 5,
#          'free': 5,
#          'world': 5,
#          'country': 5,
#          'until': 5,
#          'great': 5,
#          'want': 5,
#          'souvanna': 5,
#          'juvenile': 5,
#          'h.': 5,
#          'vital': 5,
#          'call': 5,
#          'level': 5,
#          'views': 5,
#          'reama': 5,
#          'club': 5,
#          'me': 5,
#          'movement': 5,
#          'think': 5,
#          'followed': 5,
#          'ordinance': 5,
#          'issues': 5,
#          'either': 5,
#          'open': 5,
#          'industry': 5,
#          'life': 5,
#          'sandman': 5,
#          'nomination': 5,
#          'ave.': 5,
#          'democrats': 5,
#          'lives': 5,
#          'bronx': 5,
#          'peace': 5,
#          'joint': 5,
#          'agreement': 5,
#          'pennsylvania': 5,
#          'car': 5,
#          'berger': 5,
#          'dog': 5,
#          'eastwick': 5,
#          'portland': 5,
#          'rev.': 5,
#          'superior': 4,
#          'interest': 4,
#          "georgia's": 4,
#          'end': 4,
#          'best': 4,
#          'personnel': 4,
#          'effective': 4,
#          'child': 4,
#          'homes': 4,
#          'none': 4,
#          'failure': 4,
#          'previous': 4,
#          'actions': 4,
#          'jan.': 4,
#          'jail': 4,
#          'doctor': 4,
#          'establishment': 4,
#          'georgia': 4,
#          'strong': 4,
#          "governor's": 4,
#          'audience': 4,
#          '8': 4,
#          'speaker': 4,
#          'force': 4,
#          'precincts': 4,
#          'obtain': 4,
#          'according': 4,
#          'attended': 4,
#          'wanted': 4,
#          'voted': 4,
#          'courses': 4,
#          'sam': 4,
#          'vandiver': 4,
#          'begin': 4,
#          'fund': 4,
#          'old': 4,
#          'yet': 4,
#          'offer': 4,
#          'pointed': 4,
#          'constitutional': 4,
#          'amendment': 4,
#          'sessions': 4,
#          'directed': 4,
#          'controversy': 4,
#          'ever': 4,
#          'saw': 4,
#          'votes': 4,
#          'polls': 4,
#          "didn't": 4,
#          'george': 4,
#          'p.': 4,
#          'telephone': 4,
#          'sheriff': 4,
#          'real': 4,
#          'approval': 4,
#          'bankers': 4,
#          'daniel': 4,
#          'questions': 4,
#          'little': 4,
#          '17': 4,
#          'fiscal': 4,
#          'seven': 4,
#          'banks': 4,
#          'almost': 4,
#          'lawyer': 4,
#          'confidence': 4,
#          'millions': 4,
#          'estimated': 4,
#          'coming': 4,
#          'hear': 4,
#          'expects': 4,
#          'why': 4,
#          'planning': 4,
#          'cities': 4,
#          'adopted': 4,
#          'eliminating': 4,
#          'frank': 4,
#          'suggested': 4,
#          'representatives': 4,
#          'poll': 4,
#          'april': 4,
#          'feb.': 4,
#          'choice': 4,
#          'big': 4,
#          'cotten': 4,
#          'felt': 4,
#          'grover': 4,
#          'hours': 4,
#          'required': 4,
#          'junior': 4,
#          '30': 4,
#          'rhode': 4,
#          'institute': 4,
#          'discrimination': 4,
#          'employment': 4,
#          'serious': 4,
#          'projects': 4,
#          'criminal': 4,
#          'others': 4,
#          'conflict': 4,
#          'tomorrow': 4,
#          'staff': 4,
#          'obtained': 4,
#          'morris': 4,
#          'building': 4,
#          'judges': 4,
#          '23d': 4,
#          'raised': 4,
#          'americans': 4,
#          'railroad': 4,
#          'programs': 4,
#          'message': 4,
#          'finance': 4,
#          '20': 4,
#          'already': 4,
#          'nine': 4,
#          'caused': 4,
#          "president's": 4,
#          "nation's": 4,
#          'area': 4,
#          'reaction': 4,
#          'voluntary': 4,
#          'pressure': 4,
#          '11': 4,
#          'understanding': 4,
#          'concerned': 4,
#          'never': 4,
#          'speech': 4,
#          'perhaps': 4,
#          'apparent': 4,
#          'spring': 4,
#          'interested': 4,
#          'situation': 4,
#          'raising': 4,
#          'cuba': 4,
#          'disclosed': 4,
#          'period': 4,
#          'war': 4,
#          'favor': 4,
#          'growth': 4,
#          'supported': 4,
#          'offenses': 4,
#          '1959': 4,
#          'opinion': 4,
#          'residents': 4,
#          'rescue': 4,
#          'air': 4,
#          'developed': 4,
#          'notte': 4,
#          'move': 4,
#          'enforcement': 4,
#          'thousands': 4,
#          'original': 4,
#          'retired': 4,
#          'us': 4,
#          'johnston': 4,
#          'hand': 4,
#          'posts': 4,
#          'traffic': 4,
#          'spoke': 4,
#          'westfield': 4,
#          "women's": 4,
#          'sheets': 4,
#          'necessary': 4,
#          'purchase': 4,
#          'bid': 4,
#          'green': 4,
#          'land': 4,
#          'she': 4,
#          'mates': 4,
#          'controller': 4,
#          'ticket': 4,
#          'performance': 4,
#          '16': 4,
#          'agencies': 4,
#          'stage': 4,
#          's.': 4,
#          'premier': 4,
#          'pfaff': 4,
#          'parade': 4,
#          'historic': 4,
#          'square': 4,
#          'center': 4,
#          'headed': 4,
#          'mississippi': 4,
#          'segregation': 4,
#          'revenues': 4,
#          '$28': 4,
#          'bids': 4,
#          "city's": 4,
#          'contract': 4,
#          'sue': 4,
#          'goodis': 4,
#          'hotels': 4,
#          'churches': 4,
#          'fighters': 4,
#          'teamsters': 4,
#          'thought': 4,
#          'delegates': 4,
#          'irregularities': 3,
#          'manner': 3,
#          'investigate': 3,
#          'allen': 3,
#          'commented': 3,
#          'purchasing': 3,
#          'practices': 3,
#          'achieve': 3,
#          'reduce': 3,
#          'date': 3,
#          'assistance': 3,
#          'less': 3,
#          'populous': 3,
#          'nevertheless': 3,
#          'feel': 3,
#          'available': 3,
#          'found': 3,
#          'procedures': 3,
#          'fact': 3,
#          'appointed': 3,
#          'airport': 3,
#          'eliminate': 3,
#          'keeping': 3,
#          'prices': 3,
#          'employed': 3,
#          'fair': 3,
#          'operation': 3,
#          'prison': 3,
#          'filed': 3,
#          'suit': 3,
#          'wife': 3,
#          'married': 3,
#          'berry': 3,
#          'daughter': 3,
#          'aj': 3,
#          'henry': 3,
#          'career': 3,
#          'sept.': 3,
#          'official': 3,
#          'wednesday': 3,
#          'robert': 3,
#          'entering': 3,
#          'warning': 3,
#          'largest': 3,
#          'face': 3,
#          'says': 3,
#          'alternative': 3,
#          'sign': 3,
#          'allowed': 3,
#          'resigned': 3,
#          'shortly': 3,
#          'areas': 3,
#          'likely': 3,
#          'mention': 3,
#          'earlier': 3,
#          'ready': 3,
#          'revolving': 3,
#          'issued': 3,
#          'ones': 3,
#          '1958': 3,
#          'constitution': 3,
#          'expense': 3,
#          'notice': 3,
#          'offered': 3,
#          'raises': 3,
#          'jackson': 3,
#          'barber': 3,
#          'increased': 3,
#          'provided': 3,
#          'congressmen': 3,
#          'formally': 3,
#          'event': 3,
#          'put': 3,
#          'defeated': 3,
#          'bush': 3,
#          'principal': 3,
#          'ordinary': 3,
#          'stood': 3,
#          'trouble': 3,
#          'leading': 3,
#          'anonymous': 3,
#          'promised': 3,
#          'good': 3,
#          'everything': 3,
#          'went': 3,
#          'seemed': 3,
#          'revenue': 3,
#          'recommend': 3,
#          'termed': 3,
#          'merely': 3,
#          'permits': 3,
#          'bank': 3,
#          'personal': 3,
#          'insurance': 3,
#          'cannot': 3,
#          'representing': 3,
#          'denied': 3,
#          'including': 3,
#          'scott': 3,
#          'houston': 3,
#          'howard': 3,
#          'argued': 3,
#          'introduced': 3,
#          'senators': 3,
#          'designed': 3,
#          'debate': 3,
#          'agency': 3,
#          'establish': 3,
#          'residential': 3,
#          'budget': 3,
#          "year's": 3,
#          'red': 3,
#          'joe': 3,
#          'ratcliff': 3,
#          'informed': 3,
#          'oppose': 3,
#          "i'm": 3,
#          'sent': 3,
#          'passing': 3,
#          'accept': 3,
#          'revision': 3,
#          'requirement': 3,
#          'series': 3,
#          'paris': 3,
#          'elections': 3,
#          '65': 3,
#          'kept': 3,
#          'roberts': 3,
#          'legislative': 3,
#          'fort': 3,
#          'sponsored': 3,
#          ...})

# %%
skip_grams = []

for doc in news_corpus:
    for i in range(2, len(doc)-2):
        center = doc[i]
        outside = [doc[i-2], doc[i-1], doc[i+1], doc[i+2]]
        for each_out in outside:
            skip_grams.append((center, each_out))

skip_grams
# Out:
# [('county', 'the'),
#  ('county', 'fulton'),
#  ('county', 'grand'),
#  ('county', 'jury'),
#  ('grand', 'fulton'),
#  ('grand', 'county'),
#  ('grand', 'jury'),
#  ('grand', 'said'),
#  ('jury', 'county'),
#  ('jury', 'grand'),
#  ('jury', 'said'),
#  ('jury', 'friday'),
#  ('said', 'grand'),
#  ('said', 'jury'),
#  ('said', 'friday'),
#  ('said', 'an'),
#  ('friday', 'jury'),
#  ('friday', 'said'),
#  ('friday', 'an'),
#  ('friday', 'investigation'),
#  ('an', 'said'),
#  ('an', 'friday'),
#  ('an', 'investigation'),
#  ('an', 'of'),
#  ('investigation', 'friday'),
#  ('investigation', 'an'),
#  ('investigation', 'of'),
#  ('investigation', "atlanta's"),
#  ('of', 'an'),
#  ('of', 'investigation'),
#  ('of', "atlanta's"),
#  ('of', 'recent'),
#  ("atlanta's", 'investigation'),
#  ("atlanta's", 'of'),
#  ("atlanta's", 'recent'),
#  ("atlanta's", 'primary'),
#  ('recent', 'of'),
#  ('recent', "atlanta's"),
#  ('recent', 'primary'),
#  ('recent', 'election'),
#  ('primary', "atlanta's"),
#  ('primary', 'recent'),
#  ('primary', 'election'),
#  ('primary', 'produced'),
#  ('election', 'recent'),
#  ('election', 'primary'),
#  ('election', 'produced'),
#  ('election', '``'),
#  ('produced', 'primary'),
#  ('produced', 'election'),
#  ('produced', '``'),
#  ('produced', 'no'),
#  ('``', 'election'),
#  ('``', 'produced'),
#  ('``', 'no'),
#  ('``', 'evidence'),
#  ('no', 'produced'),
#  ('no', '``'),
#  ('no', 'evidence'),
#  ('no', "''"),
#  ('evidence', '``'),
#  ('evidence', 'no'),
#  ('evidence', "''"),
#  ('evidence', 'that'),
#  ("''", 'no'),
#  ("''", 'evidence'),
#  ("''", 'that'),
#  ("''", 'any'),
#  ('that', 'evidence'),
#  ('that', "''"),
#  ('that', 'any'),
#  ('that', 'irregularities'),
#  ('any', "''"),
#  ('any', 'that'),
#  ('any', 'irregularities'),
#  ('any', 'took'),
#  ('irregularities', 'that'),
#  ('irregularities', 'any'),
#  ('irregularities', 'took'),
#  ('irregularities', 'place'),
#  ('took', 'any'),
#  ('took', 'irregularities'),
#  ('took', 'place'),
#  ('took', '.'),
#  ('further', 'the'),
#  ('further', 'jury'),
#  ('further', 'said'),
#  ('further', 'in'),
#  ('said', 'jury'),
#  ('said', 'further'),
#  ('said', 'in'),
#  ('said', 'term-end'),
#  ('in', 'further'),
#  ('in', 'said'),
#  ('in', 'term-end'),
#  ('in', 'presentments'),
#  ('term-end', 'said'),
#  ('term-end', 'in'),
#  ('term-end', 'presentments'),
#  ('term-end', 'that'),
#  ('presentments', 'in'),
#  ('presentments', 'term-end'),
#  ('presentments', 'that'),
#  ('presentments', 'the'),
#  ('that', 'term-end'),
#  ('that', 'presentments'),
#  ('that', 'the'),
#  ('that', 'city'),
#  ('the', 'presentments'),
#  ('the', 'that'),
#  ('the', 'city'),
#  ('the', 'executive'),
#  ('city', 'that'),
#  ('city', 'the'),
#  ('city', 'executive'),
#  ('city', 'committee'),
#  ('executive', 'the'),
#  ('executive', 'city'),
#  ('executive', 'committee'),
#  ('executive', ','),
#  ('committee', 'city'),
#  ('committee', 'executive'),
#  ('committee', ','),
#  ('committee', 'which'),
#  (',', 'executive'),
#  (',', 'committee'),
#  (',', 'which'),
#  (',', 'had'),
#  ('which', 'committee'),
#  ('which', ','),
#  ('which', 'had'),
#  ('which', 'over-all'),
#  ('had', ','),
#  ('had', 'which'),
#  ('had', 'over-all'),
#  ('had', 'charge'),
#  ('over-all', 'which'),
#  ('over-all', 'had'),
#  ('over-all', 'charge'),
#  ('over-all', 'of'),
#  ('charge', 'had'),
#  ('charge', 'over-all'),
#  ('charge', 'of'),
#  ('charge', 'the'),
#  ('of', 'over-all'),
#  ('of', 'charge'),
#  ('of', 'the'),
#  ('of', 'election'),
#  ('the', 'charge'),
#  ('the', 'of'),
#  ('the', 'election'),
#  ('the', ','),
#  ('election', 'of'),
#  ('election', 'the'),
#  ('election', ','),
#  ('election', '``'),
#  (',', 'the'),
#  (',', 'election'),
#  (',', '``'),
#  (',', 'deserves'),
#  ('``', 'election'),
#  ('``', ','),
#  ('``', 'deserves'),
#  ('``', 'the'),
#  ('deserves', ','),
#  ('deserves', '``'),
#  ('deserves', 'the'),
#  ('deserves', 'praise'),
#  ('the', '``'),
#  ('the', 'deserves'),
#  ('the', 'praise'),
#  ('the', 'and'),
#  ('praise', 'deserves'),
#  ('praise', 'the'),
#  ('praise', 'and'),
#  ('praise', 'thanks'),
#  ('and', 'the'),
#  ('and', 'praise'),
#  ('and', 'thanks'),
#  ('and', 'of'),
#  ('thanks', 'praise'),
#  ('thanks', 'and'),
#  ('thanks', 'of'),
#  ('thanks', 'the'),
#  ('of', 'and'),
#  ('of', 'thanks'),
#  ('of', 'the'),
#  ('of', 'city'),
#  ('the', 'thanks'),
#  ('the', 'of'),
#  ('the', 'city'),
#  ('the', 'of'),
#  ('city', 'of'),
#  ('city', 'the'),
#  ('city', 'of'),
#  ('city', 'atlanta'),
#  ('of', 'the'),
#  ('of', 'city'),
#  ('of', 'atlanta'),
#  ('of', "''"),
#  ('atlanta', 'city'),
#  ('atlanta', 'of'),
#  ('atlanta', "''"),
#  ('atlanta', 'for'),
#  ("''", 'of'),
#  ("''", 'atlanta'),
#  ("''", 'for'),
#  ("''", 'the'),
#  ('for', 'atlanta'),
#  ('for', "''"),
#  ('for', 'the'),
#  ('for', 'manner'),
#  ('the', "''"),
#  ('the', 'for'),
#  ('the', 'manner'),
#  ('the', 'in'),
#  ('manner', 'for'),
#  ('manner', 'the'),
#  ('manner', 'in'),
#  ('manner', 'which'),
#  ('in', 'the'),
#  ('in', 'manner'),
#  ('in', 'which'),
#  ('in', 'the'),
#  ('which', 'manner'),
#  ('which', 'in'),
#  ('which', 'the'),
#  ('which', 'election'),
#  ('the', 'in'),
#  ('the', 'which'),
#  ('the', 'election'),
#  ('the', 'was'),
#  ('election', 'which'),
#  ('election', 'the'),
#  ('election', 'was'),
#  ('election', 'conducted'),
#  ('was', 'the'),
#  ('was', 'election'),
#  ('was', 'conducted'),
#  ('was', '.'),
#  ('term', 'the'),
#  ('term', 'september-october'),
#  ('term', 'jury'),
#  ('term', 'had'),
#  ('jury', 'september-october'),
#  ('jury', 'term'),
#  ('jury', 'had'),
#  ('jury', 'been'),
#  ('had', 'term'),
#  ('had', 'jury'),
#  ('had', 'been'),
#  ('had', 'charged'),
#  ('been', 'jury'),
#  ('been', 'had'),
#  ('been', 'charged'),
#  ('been', 'by'),
#  ('charged', 'had'),
#  ('charged', 'been'),
#  ('charged', 'by'),
#  ('charged', 'fulton'),
#  ('by', 'been'),
#  ('by', 'charged'),
#  ('by', 'fulton'),
#  ('by', 'superior'),
#  ('fulton', 'charged'),
#  ('fulton', 'by'),
#  ('fulton', 'superior'),
#  ('fulton', 'court'),
#  ('superior', 'by'),
#  ('superior', 'fulton'),
#  ('superior', 'court'),
#  ('superior', 'judge'),
#  ('court', 'fulton'),
#  ('court', 'superior'),
#  ('court', 'judge'),
#  ('court', 'durwood'),
#  ('judge', 'superior'),
#  ('judge', 'court'),
#  ('judge', 'durwood'),
#  ('judge', 'pye'),
#  ('durwood', 'court'),
#  ('durwood', 'judge'),
#  ('durwood', 'pye'),
#  ('durwood', 'to'),
#  ('pye', 'judge'),
#  ('pye', 'durwood'),
#  ('pye', 'to'),
#  ('pye', 'investigate'),
#  ('to', 'durwood'),
#  ('to', 'pye'),
#  ('to', 'investigate'),
#  ('to', 'reports'),
#  ('investigate', 'pye'),
#  ('investigate', 'to'),
#  ('investigate', 'reports'),
#  ('investigate', 'of'),
#  ('reports', 'to'),
#  ('reports', 'investigate'),
#  ('reports', 'of'),
#  ('reports', 'possible'),
#  ('of', 'investigate'),
#  ('of', 'reports'),
#  ('of', 'possible'),
#  ('of', '``'),
#  ('possible', 'reports'),
#  ('possible', 'of'),
#  ('possible', '``'),
#  ('possible', 'irregularities'),
#  ('``', 'of'),
#  ('``', 'possible'),
#  ('``', 'irregularities'),
#  ('``', "''"),
#  ('irregularities', 'possible'),
#  ('irregularities', '``'),
#  ('irregularities', "''"),
#  ('irregularities', 'in'),
#  ("''", '``'),
#  ("''", 'irregularities'),
#  ("''", 'in'),
#  ("''", 'the'),
#  ('in', 'irregularities'),
#  ('in', "''"),
#  ('in', 'the'),
#  ('in', 'hard-fought'),
#  ('the', "''"),
#  ('the', 'in'),
#  ('the', 'hard-fought'),
#  ('the', 'primary'),
#  ('hard-fought', 'in'),
#  ('hard-fought', 'the'),
#  ('hard-fought', 'primary'),
#  ('hard-fought', 'which'),
#  ('primary', 'the'),
#  ('primary', 'hard-fought'),
#  ('primary', 'which'),
#  ('primary', 'was'),
#  ('which', 'hard-fought'),
#  ('which', 'primary'),
#  ('which', 'was'),
#  ('which', 'won'),
#  ('was', 'primary'),
#  ('was', 'which'),
#  ('was', 'won'),
#  ('was', 'by'),
#  ('won', 'which'),
#  ('won', 'was'),
#  ('won', 'by'),
#  ('won', 'mayor-nominate'),
#  ('by', 'was'),
#  ('by', 'won'),
#  ('by', 'mayor-nominate'),
#  ('by', 'ivan'),
#  ('mayor-nominate', 'won'),
#  ('mayor-nominate', 'by'),
#  ('mayor-nominate', 'ivan'),
#  ('mayor-nominate', 'allen'),
#  ('ivan', 'by'),
#  ('ivan', 'mayor-nominate'),
#  ('ivan', 'allen'),
#  ('ivan', 'jr.'),
#  ('allen', 'mayor-nominate'),
#  ('allen', 'ivan'),
#  ('allen', 'jr.'),
#  ('allen', '.'),
#  ('a', '``'),
#  ('a', 'only'),
#  ('a', 'relative'),
#  ('a', 'handful'),
#  ('relative', 'only'),
#  ('relative', 'a'),
#  ('relative', 'handful'),
#  ('relative', 'of'),
#  ('handful', 'a'),
#  ('handful', 'relative'),
#  ('handful', 'of'),
#  ('handful', 'such'),
#  ('of', 'relative'),
#  ('of', 'handful'),
#  ('of', 'such'),
#  ('of', 'reports'),
#  ('such', 'handful'),
#  ('such', 'of'),
#  ('such', 'reports'),
#  ('such', 'was'),
#  ('reports', 'of'),
#  ('reports', 'such'),
#  ('reports', 'was'),
#  ('reports', 'received'),
#  ('was', 'such'),
#  ('was', 'reports'),
#  ('was', 'received'),
#  ('was', "''"),
#  ('received', 'reports'),
#  ('received', 'was'),
#  ('received', "''"),
#  ('received', ','),
#  ("''", 'was'),
#  ("''", 'received'),
#  ("''", ','),
#  ("''", 'the'),
#  (',', 'received'),
#  (',', "''"),
#  (',', 'the'),
#  (',', 'jury'),
#  ('the', "''"),
#  ('the', ','),
#  ('the', 'jury'),
#  ('the', 'said'),
#  ('jury', ','),
#  ('jury', 'the'),
#  ('jury', 'said'),
#  ('jury', ','),
#  ('said', 'the'),
#  ('said', 'jury'),
#  ('said', ','),
#  ('said', '``'),
#  (',', 'jury'),
#  (',', 'said'),
#  (',', '``'),
#  (',', 'considering'),
#  ('``', 'said'),
#  ('``', ','),
#  ('``', 'considering'),
#  ('``', 'the'),
#  ('considering', ','),
#  ('considering', '``'),
#  ('considering', 'the'),
#  ('considering', 'widespread'),
#  ('the', '``'),
#  ('the', 'considering'),
#  ('the', 'widespread'),
#  ('the', 'interest'),
#  ('widespread', 'considering'),
#  ('widespread', 'the'),
#  ('widespread', 'interest'),
#  ('widespread', 'in'),
#  ('interest', 'the'),
#  ('interest', 'widespread'),
#  ('interest', 'in'),
#  ('interest', 'the'),
#  ('in', 'widespread'),
#  ('in', 'interest'),
#  ('in', 'the'),
#  ('in', 'election'),
#  ('the', 'interest'),
#  ('the', 'in'),
#  ('the', 'election'),
#  ('the', ','),
#  ('election', 'in'),
#  ('election', 'the'),
#  ('election', ','),
#  ('election', 'the'),
#  (',', 'the'),
#  (',', 'election'),
#  (',', 'the'),
#  (',', 'number'),
#  ('the', 'election'),
#  ('the', ','),
#  ('the', 'number'),
#  ('the', 'of'),
#  ('number', ','),
#  ('number', 'the'),
#  ('number', 'of'),
#  ('number', 'voters'),
#  ('of', 'the'),
#  ('of', 'number'),
#  ('of', 'voters'),
#  ('of', 'and'),
#  ('voters', 'number'),
#  ('voters', 'of'),
#  ('voters', 'and'),
#  ('voters', 'the'),
#  ('and', 'of'),
#  ('and', 'voters'),
#  ('and', 'the'),
#  ('and', 'size'),
#  ('the', 'voters'),
#  ('the', 'and'),
#  ('the', 'size'),
#  ('the', 'of'),
#  ('size', 'and'),
#  ('size', 'the'),
#  ('size', 'of'),
#  ('size', 'this'),
#  ('of', 'the'),
#  ('of', 'size'),
#  ('of', 'this'),
#  ('of', 'city'),
#  ('this', 'size'),
#  ('this', 'of'),
#  ('this', 'city'),
#  ('this', "''"),
#  ('city', 'of'),
#  ('city', 'this'),
#  ('city', "''"),
#  ('city', '.'),
#  ('said', 'the'),
#  ('said', 'jury'),
#  ('said', 'it'),
#  ('said', 'did'),
#  ('it', 'jury'),
#  ('it', 'said'),
#  ('it', 'did'),
#  ('it', 'find'),
#  ('did', 'said'),
#  ('did', 'it'),
#  ('did', 'find'),
#  ('did', 'that'),
#  ('find', 'it'),
#  ('find', 'did'),
#  ('find', 'that'),
#  ('find', 'many'),
#  ('that', 'did'),
#  ('that', 'find'),
#  ('that', 'many'),
#  ('that', 'of'),
#  ('many', 'find'),
#  ('many', 'that'),
#  ('many', 'of'),
#  ('many', "georgia's"),
#  ('of', 'that'),
#  ('of', 'many'),
#  ('of', "georgia's"),
#  ('of', 'registration'),
#  ("georgia's", 'many'),
#  ("georgia's", 'of'),
#  ("georgia's", 'registration'),
#  ("georgia's", 'and'),
#  ('registration', 'of'),
#  ('registration', "georgia's"),
#  ('registration', 'and'),
#  ('registration', 'election'),
#  ('and', "georgia's"),
#  ('and', 'registration'),
#  ('and', 'election'),
#  ('and', 'laws'),
#  ('election', 'registration'),
#  ('election', 'and'),
#  ('election', 'laws'),
#  ('election', '``'),
#  ('laws', 'and'),
#  ('laws', 'election'),
#  ('laws', '``'),
#  ('laws', 'are'),
#  ('``', 'election'),
#  ('``', 'laws'),
#  ('``', 'are'),
#  ('``', 'outmoded'),
#  ('are', 'laws'),
#  ('are', '``'),
#  ('are', 'outmoded'),
#  ('are', 'or'),
#  ('outmoded', '``'),
#  ('outmoded', 'are'),
#  ('outmoded', 'or'),
#  ('outmoded', 'inadequate'),
#  ('or', 'are'),
#  ('or', 'outmoded'),
#  ('or', 'inadequate'),
#  ('or', 'and'),
#  ('inadequate', 'outmoded'),
#  ('inadequate', 'or'),
#  ('inadequate', 'and'),
#  ('inadequate', 'often'),
#  ('and', 'or'),
#  ('and', 'inadequate'),
#  ('and', 'often'),
#  ('and', 'ambiguous'),
#  ('often', 'inadequate'),
#  ('often', 'and'),
#  ('often', 'ambiguous'),
#  ('often', "''"),
#  ('ambiguous', 'and'),
#  ('ambiguous', 'often'),
#  ('ambiguous', "''"),
#  ('ambiguous', '.'),
#  ('that', 'it'),
#  ('that', 'recommended'),
#  ('that', 'fulton'),
#  ('that', 'legislators'),
#  ('fulton', 'recommended'),
#  ('fulton', 'that'),
#  ('fulton', 'legislators'),
#  ('fulton', 'act'),
#  ('legislators', 'that'),
#  ('legislators', 'fulton'),
#  ('legislators', 'act'),
#  ('legislators', '``'),
#  ('act', 'fulton'),
#  ('act', 'legislators'),
#  ('act', '``'),
#  ('act', 'to'),
#  ('``', 'legislators'),
#  ('``', 'act'),
#  ('``', 'to'),
#  ('``', 'have'),
#  ('to', 'act'),
#  ('to', '``'),
#  ('to', 'have'),
#  ('to', 'these'),
#  ('have', '``'),
#  ('have', 'to'),
#  ('have', 'these'),
#  ('have', 'laws'),
#  ('these', 'to'),
#  ('these', 'have'),
#  ('these', 'laws'),
#  ('these', 'studied'),
#  ('laws', 'have'),
#  ('laws', 'these'),
#  ('laws', 'studied'),
#  ('laws', 'and'),
#  ('studied', 'these'),
#  ('studied', 'laws'),
#  ('studied', 'and'),
#  ('studied', 'revised'),
#  ('and', 'laws'),
#  ('and', 'studied'),
#  ('and', 'revised'),
#  ('and', 'to'),
#  ('revised', 'studied'),
#  ('revised', 'and'),
#  ('revised', 'to'),
#  ('revised', 'the'),
#  ('to', 'and'),
#  ('to', 'revised'),
#  ('to', 'the'),
#  ('to', 'end'),
#  ('the', 'revised'),
#  ('the', 'to'),
#  ('the', 'end'),
#  ('the', 'of'),
#  ('end', 'to'),
#  ('end', 'the'),
#  ('end', 'of'),
#  ('end', 'modernizing'),
#  ('of', 'the'),
#  ('of', 'end'),
#  ('of', 'modernizing'),
#  ('of', 'and'),
#  ('modernizing', 'end'),
#  ('modernizing', 'of'),
#  ('modernizing', 'and'),
#  ('modernizing', 'improving'),
#  ('and', 'of'),
#  ('and', 'modernizing'),
#  ('and', 'improving'),
#  ('and', 'them'),
#  ('improving', 'modernizing'),
#  ('improving', 'and'),
#  ('improving', 'them'),
#  ('improving', "''"),
#  ('them', 'and'),
#  ('them', 'improving'),
#  ('them', "''"),
#  ('them', '.'),
#  ('jury', 'the'),
#  ('jury', 'grand'),
#  ('jury', 'commented'),
#  ('jury', 'on'),
#  ('commented', 'grand'),
#  ('commented', 'jury'),
#  ('commented', 'on'),
#  ('commented', 'a'),
#  ('on', 'jury'),
#  ('on', 'commented'),
#  ('on', 'a'),
#  ('on', 'number'),
#  ('a', 'commented'),
#  ('a', 'on'),
#  ('a', 'number'),
#  ('a', 'of'),
#  ('number', 'on'),
#  ('number', 'a'),
#  ('number', 'of'),
#  ('number', 'other'),
#  ('of', 'a'),
#  ('of', 'number'),
#  ('of', 'other'),
#  ('of', 'topics'),
#  ('other', 'number'),
#  ('other', 'of'),
#  ('other', 'topics'),
#  ('other', ','),
#  ('topics', 'of'),
#  ('topics', 'other'),
#  ('topics', ','),
#  ('topics', 'among'),
#  (',', 'other'),
#  (',', 'topics'),
#  (',', 'among'),
#  (',', 'them'),
#  ('among', 'topics'),
#  ('among', ','),
#  ('among', 'them'),
#  ('among', 'the'),
#  ('them', ','),
#  ('them', 'among'),
#  ('them', 'the'),
#  ('them', 'atlanta'),
#  ('the', 'among'),
#  ('the', 'them'),
#  ('the', 'atlanta'),
#  ('the', 'and'),
#  ('atlanta', 'them'),
#  ('atlanta', 'the'),
#  ('atlanta', 'and'),
#  ('atlanta', 'fulton'),
#  ('and', 'the'),
#  ('and', 'atlanta'),
#  ('and', 'fulton'),
#  ('and', 'county'),
#  ('fulton', 'atlanta'),
#  ('fulton', 'and'),
#  ('fulton', 'county'),
#  ('fulton', 'purchasing'),
#  ('county', 'and'),
#  ('county', 'fulton'),
#  ('county', 'purchasing'),
#  ('county', 'departments'),
#  ('purchasing', 'fulton'),
#  ('purchasing', 'county'),
#  ('purchasing', 'departments'),
#  ('purchasing', 'which'),
#  ('departments', 'county'),
#  ('departments', 'purchasing'),
#  ('departments', 'which'),
#  ('departments', 'it'),
#  ('which', 'purchasing'),
#  ('which', 'departments'),
#  ('which', 'it'),
#  ('which', 'said'),
#  ('it', 'departments'),
#  ('it', 'which'),
#  ('it', 'said'),
#  ('it', '``'),
#  ('said', 'which'),
#  ('said', 'it'),
#  ('said', '``'),
#  ('said', 'are'),
#  ('``', 'it'),
#  ('``', 'said'),
#  ('``', 'are'),
#  ('``', 'well'),
#  ('are', 'said'),
#  ('are', '``'),
#  ('are', 'well'),
#  ('are', 'operated'),
#  ('well', '``'),
#  ('well', 'are'),
#  ('well', 'operated'),
#  ('well', 'and'),
#  ('operated', 'are'),
#  ('operated', 'well'),
#  ('operated', 'and'),
#  ('operated', 'follow'),
#  ('and', 'well'),
#  ('and', 'operated'),
#  ('and', 'follow'),
#  ('and', 'generally'),
#  ('follow', 'operated'),
#  ('follow', 'and'),
#  ('follow', 'generally'),
#  ('follow', 'accepted'),
#  ('generally', 'and'),
#  ('generally', 'follow'),
#  ('generally', 'accepted'),
#  ('generally', 'practices'),
#  ('accepted', 'follow'),
#  ('accepted', 'generally'),
#  ('accepted', 'practices'),
#  ('accepted', 'which'),
#  ('practices', 'generally'),
#  ('practices', 'accepted'),
#  ('practices', 'which'),
#  ('practices', 'inure'),
#  ('which', 'accepted'),
#  ('which', 'practices'),
#  ('which', 'inure'),
#  ('which', 'to'),
#  ('inure', 'practices'),
#  ('inure', 'which'),
#  ('inure', 'to'),
#  ('inure', 'the'),
#  ('to', 'which'),
#  ('to', 'inure'),
#  ('to', 'the'),
#  ('to', 'best'),
#  ('the', 'inure'),
#  ('the', 'to'),
#  ('the', 'best'),
#  ('the', 'interest'),
#  ('best', 'to'),
#  ('best', 'the'),
#  ('best', 'interest'),
#  ('best', 'of'),
#  ('interest', 'the'),
#  ('interest', 'best'),
#  ('interest', 'of'),
#  ('interest', 'both'),
#  ('of', 'best'),
#  ('of', 'interest'),
#  ('of', 'both'),
#  ('of', 'governments'),
#  ('both', 'interest'),
#  ('both', 'of'),
#  ('both', 'governments'),
#  ('both', "''"),
#  ('governments', 'of'),
#  ('governments', 'both'),
#  ('governments', "''"),
#  ('governments', '.'),
#  ('the', 'however'),
#  ('the', ','),
#  ('the', 'jury'),
#  ('the', 'said'),
#  ('jury', ','),
#  ('jury', 'the'),
#  ('jury', 'said'),
#  ('jury', 'it'),
#  ('said', 'the'),
#  ('said', 'jury'),
#  ('said', 'it'),
#  ('said', 'believes'),
#  ('it', 'jury'),
#  ('it', 'said'),
#  ('it', 'believes'),
#  ('it', '``'),
#  ('believes', 'said'),
#  ('believes', 'it'),
#  ('believes', '``'),
#  ('believes', 'these'),
#  ('``', 'it'),
#  ('``', 'believes'),
#  ('``', 'these'),
#  ('``', 'two'),
#  ('these', 'believes'),
#  ('these', '``'),
#  ('these', 'two'),
#  ('these', 'offices'),
#  ('two', '``'),
#  ('two', 'these'),
#  ('two', 'offices'),
#  ('two', 'should'),
#  ('offices', 'these'),
#  ('offices', 'two'),
#  ('offices', 'should'),
#  ('offices', 'be'),
#  ('should', 'two'),
#  ('should', 'offices'),
#  ('should', 'be'),
#  ('should', 'combined'),
#  ('be', 'offices'),
#  ('be', 'should'),
#  ('be', 'combined'),
#  ('be', 'to'),
#  ('combined', 'should'),
#  ('combined', 'be'),
#  ('combined', 'to'),
#  ('combined', 'achieve'),
#  ('to', 'be'),
#  ('to', 'combined'),
#  ('to', 'achieve'),
#  ('to', 'greater'),
#  ('achieve', 'combined'),
#  ('achieve', 'to'),
#  ('achieve', 'greater'),
#  ('achieve', 'efficiency'),
#  ('greater', 'to'),
#  ('greater', 'achieve'),
#  ('greater', 'efficiency'),
#  ('greater', 'and'),
#  ('efficiency', 'achieve'),
#  ('efficiency', 'greater'),
#  ('efficiency', 'and'),
#  ('efficiency', 'reduce'),
#  ('and', 'greater'),
#  ('and', 'efficiency'),
#  ('and', 'reduce'),
#  ('and', 'the'),
#  ('reduce', 'efficiency'),
#  ('reduce', 'and'),
#  ('reduce', 'the'),
#  ('reduce', 'cost'),
#  ('the', 'and'),
#  ('the', 'reduce'),
#  ('the', 'cost'),
#  ('the', 'of'),
#  ('cost', 'reduce'),
#  ('cost', 'the'),
#  ('cost', 'of'),
#  ('cost', 'administration'),
#  ('of', 'the'),
#  ('of', 'cost'),
#  ('of', 'administration'),
#  ('of', "''"),
#  ('administration', 'cost'),
#  ('administration', 'of'),
#  ('administration', "''"),
#  ('administration', '.'),
#  ('purchasing', 'the'),
#  ('purchasing', 'city'),
#  ('purchasing', 'department'),
#  ('purchasing', ','),
#  ('department', 'city'),
#  ('department', 'purchasing'),
#  ('department', ','),
#  ('department', 'the'),
#  (',', 'purchasing'),
#  (',', 'department'),
#  (',', 'the'),
#  (',', 'jury'),
#  ('the', 'department'),
#  ('the', ','),
#  ('the', 'jury'),
#  ('the', 'said'),
#  ('jury', ','),
#  ('jury', 'the'),
#  ('jury', 'said'),
#  ('jury', ','),
#  ('said', 'the'),
#  ('said', 'jury'),
#  ('said', ','),
#  ('said', '``'),
#  (',', 'jury'),
#  (',', 'said'),
#  (',', '``'),
#  (',', 'is'),
#  ('``', 'said'),
#  ('``', ','),
#  ('``', 'is'),
#  ('``', 'lacking'),
#  ('is', ','),
#  ('is', '``'),
#  ('is', 'lacking'),
#  ('is', 'in'),
#  ('lacking', '``'),
#  ('lacking', 'is'),
#  ('lacking', 'in'),
#  ('lacking', 'experienced'),
#  ('in', 'is'),
#  ('in', 'lacking'),
#  ('in', 'experienced'),
#  ('in', 'clerical'),
#  ('experienced', 'lacking'),
#  ('experienced', 'in'),
#  ('experienced', 'clerical'),
#  ('experienced', 'personnel'),
#  ('clerical', 'in'),
#  ('clerical', 'experienced'),
#  ('clerical', 'personnel'),
#  ('clerical', 'as'),
#  ('personnel', 'experienced'),
#  ('personnel', 'clerical'),
#  ('personnel', 'as'),
#  ('personnel', 'a'),
#  ('as', 'clerical'),
#  ('as', 'personnel'),
#  ('as', 'a'),
#  ('as', 'result'),
#  ('a', 'personnel'),
#  ('a', 'as'),
#  ('a', 'result'),
#  ('a', 'of'),
#  ('result', 'as'),
#  ('result', 'a'),
#  ('result', 'of'),
#  ('result', 'city'),
#  ('of', 'a'),
#  ('of', 'result'),
#  ('of', 'city'),
#  ('of', 'personnel'),
#  ('city', 'result'),
#  ('city', 'of'),
#  ('city', 'personnel'),
#  ('city', 'policies'),
#  ('personnel', 'of'),
#  ('personnel', 'city'),
#  ('personnel', 'policies'),
#  ('personnel', "''"),
#  ('policies', 'city'),
#  ('policies', 'personnel'),
#  ('policies', "''"),
#  ('policies', '.'),
#  ('that', 'it'),
#  ('that', 'urged'),
#  ('that', 'the'),
#  ('that', 'city'),
#  ('the', 'urged'),
#  ('the', 'that'),
#  ('the', 'city'),
#  ('the', '``'),
#  ('city', 'that'),
#  ('city', 'the'),
#  ('city', '``'),
#  ('city', 'take'),
#  ('``', 'the'),
#  ('``', 'city'),
#  ('``', 'take'),
#  ('``', 'steps'),
#  ...]

# %%
X_ik_skipgrams = Counter(skip_grams)
X_ik_skipgrams
# Out:
# Counter({('of', 'the'): 376,
#          ('the', 'of'): 368,
#          (',', 'the'): 189,
#          ('the', ','): 181,
#          ('the', 'in'): 173,
#          ('in', 'the'): 173,
#          ('to', 'the'): 162,
#          ('the', 'to'): 162,
#          (',', ','): 101,
#          (',', 'said'): 92,
#          ('for', 'the'): 91,
#          ('the', 'for'): 91,
#          ('of', 'a'): 86,
#          (',', 'and'): 84,
#          ('and', ','): 82,
#          ('a', 'of'): 80,
#          ('the', '.'): 79,
#          ('on', 'the'): 76,
#          ('the', 'on'): 75,
#          ('the', 'and'): 74,
#          ('and', 'the'): 74,
#          ('said', ','): 70,
#          ('to', 'a'): 68,
#          ('a', 'to'): 66,
#          ('that', 'the'): 65,
#          ('the', 'that'): 65,
#          (',', 'of'): 64,
#          ('of', ','): 63,
#          ('he', ','): 63,
#          (',', 'he'): 63,
#          ("''", ','): 54,
#          (',', "''"): 54,
#          ('a', ','): 54,
#          (',', 'a'): 53,
#          (',', 'in'): 46,
#          ('he', 'said'): 46,
#          ('be', 'to'): 45,
#          ('to', 'be'): 45,
#          ('by', 'the'): 43,
#          ('the', 'by'): 42,
#          ('the', 'state'): 42,
#          ('the', "''"): 41,
#          ('been', 'has'): 41,
#          ('in', ','): 41,
#          ('be', 'would'): 41,
#          ('at', 'the'): 40,
#          ('the', 'at'): 40,
#          ('state', 'the'): 39,
#          ('is', 'the'): 39,
#          ('and', 'of'): 38,
#          ('of', 'and'): 38,
#          ('would', 'be'): 37,
#          ('the', 'said'): 36,
#          ('has', 'been'): 35,
#          ('in', 'a'): 35,
#          ('a', 'in'): 35,
#          ('be', 'will'): 35,
#          (',', '``'): 34,
#          ('for', 'a'): 34,
#          ('a', 'for'): 34,
#          ('said', 'he'): 34,
#          ('``', ','): 33,
#          (',', 'to'): 33,
#          ('said', 'the'): 32,
#          ('the', 'with'): 32,
#          ('with', 'the'): 32,
#          ('the', 'administration'): 32,
#          ('administration', 'the'): 32,
#          ('to', ','): 32,
#          ('the', 'is'): 32,
#          ("''", 'the'): 31,
#          ('will', 'be'): 31,
#          ('it', ','): 30,
#          ('the', '``'): 29,
#          ('who', ','): 29,
#          ('the', 'city'): 28,
#          ('``', 'the'): 28,
#          ('was', 'the'): 28,
#          (',', 'it'): 28,
#          ('and', 'a'): 28,
#          ('a', 'and'): 28,
#          ('to', 'is'): 28,
#          ('a', 'is'): 28,
#          ('is', ','): 27,
#          ('city', 'the'): 26,
#          ('that', 'he'): 26,
#          ('from', 'the'): 26,
#          (',', 'is'): 25,
#          ('of', '.'): 25,
#          (',', 'who'): 25,
#          ('the', 'as'): 24,
#          ('as', 'the'): 24,
#          ('the', 'from'): 24,
#          ('was', ','): 24,
#          ('would', 'the'): 24,
#          ('is', 'to'): 24,
#          ('the', 'was'): 23,
#          ('a', 'on'): 23,
#          ('in', '.'): 23,
#          (',', 'was'): 23,
#          ('that', ','): 23,
#          ('the', 'house'): 23,
#          (',', 'which'): 22,
#          ('which', ','): 22,
#          ('a', '``'): 22,
#          ('on', 'a'): 22,
#          ('as', 'a'): 22,
#          ('a', 'as'): 22,
#          (',', 'that'): 22,
#          ('the', 'united'): 22,
#          ('united', 'the'): 22,
#          ('states', 'the'): 22,
#          ('in', 'and'): 21,
#          ('will', 'the'): 21,
#          ('has', 'the'): 21,
#          ('more', 'than'): 21,
#          ('than', 'more'): 21,
#          ('the', 'would'): 21,
#          ('is', 'a'): 21,
#          ('of', 'in'): 21,
#          ('in', 'of'): 21,
#          ('``', "''"): 20,
#          ('of', 'one'): 20,
#          ('and', 'in'): 20,
#          ('the', 'party'): 20,
#          ('to', 'to'): 20,
#          ('the', 'states'): 20,
#          ("''", '``'): 19,
#          ('``', 'said'): 19,
#          ('``', 'a'): 19,
#          ('as', ','): 19,
#          (',', 'as'): 19,
#          ('a', 'year'): 19,
#          ('he', 'that'): 19,
#          ('has', ','): 19,
#          ('house', 'the'): 19,
#          ('bill', 'the'): 19,
#          ('states', 'united'): 19,
#          ('the', 'legislature'): 18,
#          ('to', 'in'): 18,
#          ('in', 'to'): 18,
#          (',', 'has'): 18,
#          ('session', 'the'): 18,
#          ('the', 'first'): 18,
#          ('first', 'the'): 18,
#          ('for', 'of'): 18,
#          ('of', 'for'): 18,
#          (',', 'for'): 18,
#          ('for', ','): 18,
#          ('and', 'to'): 17,
#          ('to', 'and'): 17,
#          ('one', 'of'): 17,
#          ('the', 'will'): 17,
#          (',', '.'): 17,
#          ('that', 'said'): 17,
#          ('the', 'has'): 17,
#          ('party', 'the'): 17,
#          ('the', 'session'): 17,
#          ('to', 'an'): 17,
#          ('an', 'to'): 17,
#          ('united', 'states'): 17,
#          (',', 'mr.'): 17,
#          ('of', "''"): 16,
#          ('to', 'have'): 16,
#          ('have', 'to'): 16,
#          (',', 'but'): 16,
#          ('but', ','): 16,
#          ('of', 'some'): 16,
#          ('a', '.'): 16,
#          ('to', 'for'): 16,
#          ('for', 'to'): 16,
#          ('with', 'a'): 16,
#          ('a', 'with'): 16,
#          ('year', 'a'): 16,
#          ('state', 'of'): 16,
#          ('of', 'state'): 16,
#          ('by', ','): 16,
#          ('the', 'committee'): 16,
#          ('would', ','): 16,
#          ('the', 'bill'): 16,
#          ('to', '.'): 16,
#          ('as', 'as'): 16,
#          ('the', 'republican'): 16,
#          ('republican', 'the'): 16,
#          ('be', 'should'): 15,
#          ('legislature', 'the'): 15,
#          ('some', 'of'): 15,
#          ('to', 'it'): 15,
#          (',', 'by'): 15,
#          ('committee', 'the'): 15,
#          ('of', 'his'): 15,
#          ('the', 'council'): 15,
#          ('council', 'the'): 15,
#          ('by', 'was'): 14,
#          ('said', '``'): 14,
#          ('that', 'it'): 14,
#          ('to', '``'): 14,
#          ('the', 'be'): 14,
#          ('be', 'the'): 14,
#          ('it', 'to'): 14,
#          ('to', 'make'): 14,
#          ('to', 'would'): 14,
#          ('general', 'the'): 14,
#          ('by', 'a'): 14,
#          ('a', 'by'): 14,
#          (',', 'would'): 14,
#          ("''", 'he'): 14,
#          ('he', "''"): 14,
#          ('his', 'of'): 14,
#          ('of', 'of'): 14,
#          ('president', 'of'): 14,
#          ('of', 'president'): 14,
#          ('the', 'president'): 14,
#          ('president', 'the'): 14,
#          ('the', 'democratic'): 14,
#          ('democratic', 'the'): 14,
#          ('the', 'election'): 13,
#          ('election', 'the'): 13,
#          ('which', 'the'): 13,
#          ('been', 'had'): 13,
#          ('was', 'by'): 13,
#          ('``', 'to'): 13,
#          ('should', 'be'): 13,
#          ('is', 'in'): 13,
#          ('in', 'is'): 13,
#          ('of', 'is'): 13,
#          ('the', 'one'): 13,
#          ('tax', 'the'): 13,
#          ('that', 'would'): 13,
#          ('would', 'that'): 13,
#          ('was', 'a'): 13,
#          ('make', 'to'): 13,
#          ('would', 'to'): 13,
#          ('the', 'general'): 13,
#          ('expected', 'is'): 13,
#          ('to', 'up'): 13,
#          ('that', 'is'): 13,
#          ('mr.', ','): 13,
#          ('said', 'mr.'): 13,
#          ('an', 'of'): 12,
#          ('of', 'an'): 12,
#          ('of', '``'): 12,
#          ('the', 'jury'): 12,
#          ('a', 'at'): 12,
#          ('(', ')'): 12,
#          ('for', 'and'): 12,
#          ('and', 'for'): 12,
#          ('and', "''"): 12,
#          ('the', 'tax'): 12,
#          (',', 'with'): 12,
#          ('with', ','): 12,
#          ('state', ','): 12,
#          ('was', 'that'): 12,
#          ('a', 'was'): 12,
#          ('expected', 'to'): 12,
#          ('to', 'expected'): 12,
#          ('to', 'go'): 12,
#          (',', 'bill'): 12,
#          ('he', '.'): 12,
#          ('schools', 'the'): 12,
#          ('the', 'schools'): 12,
#          ('up', 'to'): 12,
#          ('is', 'that'): 12,
#          ('not', 'is'): 12,
#          ('state', 'and'): 12,
#          ('and', 'state'): 12,
#          ('the', 'people'): 12,
#          ('people', 'the'): 12,
#          ('the', 'government'): 12,
#          ('an', 'in'): 12,
#          ('in', 'an'): 12,
#          ('last', 'the'): 12,
#          ('of', 'city'): 11,
#          ('city', 'of'): 11,
#          ("''", 'of'): 11,
#          ('the', 'which'): 11,
#          ('had', 'been'): 11,
#          ('``', 'of'): 11,
#          ('jury', 'the'): 11,
#          ('it', 'said'): 11,
#          ('to', "''"): 11,
#          ('at', 'a'): 11,
#          ('the', 'but'): 11,
#          ('in', 'state'): 11,
#          ('and', '.'): 11,
#          ('be', 'in'): 11,
#          ('in', 'be'): 11,
#          ('a', 'that'): 11,
#          ('that', 'a'): 11,
#          ('said', 'that'): 11,
#          ('to', 'his'): 11,
#          ('be', 'by'): 11,
#          ('by', 'be'): 11,
#          ('for', '.'): 11,
#          (',', 'state'): 11,
#          ('that', 'was'): 11,
#          ('meeting', 'the'): 11,
#          ('the', 'meeting'): 11,
#          ('a', 'there'): 11,
#          ('is', 'expected'): 11,
#          ('it', 'was'): 11,
#          ('was', 'it'): 11,
#          ('go', 'to'): 11,
#          ('and', 'other'): 11,
#          ('other', 'and'): 11,
#          ('to', 'their'): 11,
#          ('their', 'to'): 11,
#          ('out', 'of'): 11,
#          ('of', 'out'): 11,
#          ('bill', ','): 11,
#          ('of', 'to'): 11,
#          ('to', 'of'): 11,
#          ('last', 'year'): 11,
#          ('the', 'year'): 11,
#          ('government', 'the'): 11,
#          ('of', 'secretary'): 11,
#          ('the', 'last'): 11,
#          ('the', 'project'): 11,
#          ('county', 'the'): 10,
#          ('jury', ','): 10,
#          ('of', 'number'): 10,
#          ('this', "''"): 10,
#          ('said', 'it'): 10,
#          ('department', 'the'): 10,
#          ('is', '``'): 10,
#          ('is', 'of'): 10,
#          ('one', 'the'): 10,
#          ('state', 'in'): 10,
#          ('``', 'that'): 10,
#          ('that', '``'): 10,
#          ('not', 'did'): 10,
#          ('not', ','): 10,
#          (',', 'not'): 10,
#          ('and', '``'): 10,
#          (',', 'his'): 10,
#          ('has', 'not'): 10,
#          ('not', 'has'): 10,
#          ('his', 'to'): 10,
#          ('in', 'city'): 10,
#          ('would', 'it'): 10,
#          ('it', 'would'): 10,
#          ('the', 'senate'): 10,
#          ('senate', 'the'): 10,
#          ('be', '.'): 10,
#          ('the', 'sales'): 10,
#          ('sales', 'the'): 10,
#          ('vote', 'the'): 10,
#          ('the', 'vote'): 10,
#          ('in', 'his'): 10,
#          ('his', 'in'): 10,
#          (',', 'will'): 10,
#          ('will', ','): 10,
#          ('board', 'the'): 10,
#          ('was', 'to'): 10,
#          ('to', 'was'): 10,
#          ('out', 'the'): 10,
#          ('the', 'out'): 10,
#          ('the', 'after'): 10,
#          (',', 'an'): 10,
#          ('an', ','): 10,
#          (',', 'general'): 10,
#          ('the', 'most'): 10,
#          ('the', 'time'): 10,
#          ('c.', ','): 10,
#          (',', 'c.'): 10,
#          ('been', 'have'): 10,
#          ('between', 'the'): 10,
#          ('the', 'between'): 10,
#          ('over', 'the'): 10,
#          ('the', 'over'): 10,
#          ('work', 'the'): 10,
#          (',', 'on'): 10,
#          ('he', 'was'): 10,
#          ('was', 'he'): 10,
#          (',', 'jury'): 9,
#          ('number', 'of'): 9,
#          ('take', 'to'): 9,
#          ('to', 'take'): 9,
#          ("''", 'to'): 9,
#          ('this', 'in'): 9,
#          ('in', 'this'): 9,
#          ('the', 'it'): 9,
#          ('when', 'the'): 9,
#          ('the', 'when'): 9,
#          ('the', 'new'): 9,
#          ('new', 'the'): 9,
#          ('did', 'not'): 9,
#          ('be', 'there'): 9,
#          ('``', 'and'): 9,
#          ('be', 'for'): 9,
#          ('for', 'be'): 9,
#          ("''", 'and'): 9,
#          (',', 'since'): 9,
#          ('since', ','): 9,
#          ('city', 'in'): 9,
#          ('he', 'would'): 9,
#          ('would', 'he'): 9,
#          ('would', 'have'): 9,
#          ('have', 'would'): 9,
#          ('cent', 'per'): 9,
#          (',', 'or'): 9,
#          ('the', 'some'): 9,
#          ('with', 'in'): 9,
#          ('the', 'against'): 9,
#          ('against', 'the'): 9,
#          ('that', 'has'): 9,
#          ('has', 'that'): 9,
#          ('to', 'on'): 9,
#          ('on', 'to'): 9,
#          ('the', 'board'): 9,
#          ('to', 'pay'): 9,
#          ('pay', 'to'): 9,
#          ('other', 'the'): 9,
#          ('from', 'to'): 9,
#          ('to', 'from'): 9,
#          ('a', 'bill'): 9,
#          ('bill', 'a'): 9,
#          ('a', 'special'): 9,
#          ('special', 'a'): 9,
#          ('general', ','): 9,
#          ('most', 'the'): 9,
#          ('time', 'the'): 9,
#          ('is', 'not'): 9,
#          ('in', 'was'): 9,
#          ('have', 'been'): 9,
#          ('for', 'called'): 9,
#          ('the', 'are'): 9,
#          ('white', 'house'): 9,
#          ('the', 'work'): 9,
#          ('the', 'or'): 9,
#          ('or', 'the'): 9,
#          ('the', 'precinct'): 9,
#          ('precinct', 'the'): 9,
#          ('the', 'ward'): 9,
#          ('per', 'cent'): 9,
#          ('the', '--'): 9,
#          ('are', 'the'): 9,
#          ('on', ','): 9,
#          ('amount', 'the'): 9,
#          ('the', 'amount'): 9,
#          ('to', 'them'): 9,
#          ('secretary', 'of'): 9,
#          ('the', 'national'): 9,
#          ('national', 'the'): 9,
#          ('added', ','): 9,
#          ('said', 'jury'): 8,
#          ('election', ','): 8,
#          (',', 'election'): 8,
#          ('the', 'primary'): 8,
#          ('that', 'of'): 8,
#          ('of', 'that'): 8,
#          ('are', '``'): 8,
#          ('the', 'department'): 8,
#          ('this', '.'): 8,
#          ('the', 'next'): 8,
#          ('next', 'the'): 8,
#          ('the', 'county'): 8,
#          ('but', 'the'): 8,
#          ('we', ','): 8,
#          ('to', 'do'): 8,
#          ('do', 'to'): 8,
#          ('it', 'the'): 8,
#          ('it', 'that'): 8,
#          ('a', 'have'): 8,
#          ('as', '.'): 8,
#          ('of', 'as'): 8,
#          ('as', 'of'): 8,
#          ('present', 'the'): 8,
#          ('a', 'candidate'): 8,
#          ('candidate', 'a'): 8,
#          ('not', 'he'): 8,
#          ('not', 'would'): 8,
#          ('to', 'state'): 8,
#          ('in', 'county'): 8,
#          ('county', 'in'): 8,
#          ('of', 'on'): 8,
#          ('on', 'of'): 8,
#          ('under', 'the'): 8,
#          ('the', 'under'): 8,
#          ('director', ','): 8,
#          (',', 'director'): 8,
#          ('who', 'been'): 8,
#          ('been', 'who'): 8,
#          ('some', 'the'): 8,
#          ('for', 'in'): 8,
#          ('in', 'for'): 8,
#          ('in', 'with'): 8,
#          ('the', 'resolution'): 8,
#          ('passed', 'the'): 8,
#          ('to', 'federal'): 8,
#          ('federal', 'to'): 8,
#          ('members', 'of'): 8,
#          ('of', 'members'): 8,
#          ('board', 'of'): 8,
#          ('of', 'board'): 8,
#          ('to', 'give'): 8,
#          ('give', 'to'): 8,
#          ('a', 'new'): 8,
#          ('new', 'a'): 8,
#          ('chairman', 'the'): 8,
#          ('the', 'chairman'): 8,
#          ('had', 'he'): 8,
#          ('been', 'the'): 8,
#          ('the', 'been'): 8,
#          ('the', 'texas'): 8,
#          ('texas', 'the'): 8,
#          ('would', 'said'): 8,
#          ('the', 'other'): 8,
#          ('day', 'the'): 8,
#          ('schools', ','): 8,
#          (',', 'schools'): 8,
#          ('after', 'the'): 8,
#          ('get', 'to'): 8,
#          ('to', 'get'): 8,
#          ('are', 'to'): 8,
#          ('to', 'are'): 8,
#          ("'", "'"): 8,
#          ('this', ','): 8,
#          (',', 'this'): 8,
#          ('the', 'need'): 8,
#          ('need', 'the'): 8,
#          ('and', 'that'): 8,
#          ('that', 'and'): 8,
#          ('public', 'the'): 8,
#          ('or', ','): 8,
#          ('to', 'not'): 8,
#          ('martin', ','): 8,
#          ('able', 'to'): 8,
#          ('to', 'able'): 8,
#          ('two', 'the'): 8,
#          (',', 'if'): 8,
#          ('if', ','): 8,
#          ('kennedy', 'president'): 8,
#          ('house', 'white'): 8,
#          ('was', 'said'): 8,
#          ('the', 'had'): 8,
#          ('ward', 'the'): 8,
#          ('not', 'the'): 8,
#          ('the', 'not'): 8,
#          ('medical', 'and'): 8,
#          ('and', 'medical'): 8,
#          ('in', 'last'): 8,
#          ('last', 'in'): 8,
#          ('--', 'the'): 8,
#          ('year', 'the'): 8,
#          ('to', 'states'): 8,
#          ('states', 'to'): 8,
#          ('a', 'program'): 8,
#          ('to', 'or'): 8,
#          ('or', 'to'): 8,
#          ('them', 'to'): 8,
#          ('session', 'of'): 8,
#          ('of', 'session'): 8,
#          ('the', 'union'): 8,
#          ('the', 'question'): 8,
#          ('question', 'the'): 8,
#          ('and', 'mr.'): 8,
#          ('of', 'new'): 8,
#          ('new', 'of'): 8,
#          ('mr.', 'said'): 8,
#          ('the', 'local'): 8,
#          ('local', 'the'): 8,
#          (',', 'added'): 8,
#          (',', 'hughes'): 8,
#          ('and', 'is'): 8,
#          ('bill', 'tax'): 8,
#          ('for', "''"): 7,
#          ('in', 'which'): 7,
#          ('which', 'in'): 7,
#          ('primary', 'the'): 7,
#          ('of', 'this'): 7,
#          ('``', 'are'): 7,
#          ('of', 'other'): 7,
#          ('be', 'may'): 7,
#          ('of', 'all'): 7,
#          ('all', 'of'): 7,
#          ('on', "''"): 7,
#          ('its', 'in'): 7,
#          ('in', 'its'): 7,
#          ('that', 'will'): 7,
#          ('will', 'that'): 7,
#          ('that', 'there'): 7,
#          ('there', 'that'): 7,
#          ('there', 'be'): 7,
#          ('be', 'at'): 7,
#          ('at', 'be'): 7,
#          ('his', ','): 7,
#          ('as', 'and'): 7,
#          ('and', 'as'): 7,
#          ('city', 'council'): 7,
#          ('council', 'city'): 7,
#          ('a', 'who'): 7,
#          ('would', 'not'): 7,
#          (',', 'there'): 7,
#          ('there', ','): 7,
#          ('more', 'to'): 7,
#          ('to', 'more'): 7,
#          ('must', 'be'): 7,
#          ('be', 'must'): 7,
#          ('who', 'has'): 7,
#          ('has', 'who'): 7,
#          ('for', 'home'): 7,
#          ('home', 'for'): 7,
#          ('million', 'of'): 7,
#          ('of', 'million'): 7,
#          ('work', 'on'): 7,
#          ('on', 'work'): 7,
#          ('his', 'for'): 7,
#          ('for', 'his'): 7,
#          ('the', 'battle'): 7,
#          ('a', 'will'): 7,
#          ('the', 'passed'): 7,
#          ('to', 'aid'): 7,
#          ('federal', 'for'): 7,
#          ('for', 'federal'): 7,
#          ('state', '.'): 7,
#          ('in', 'washington'): 7,
#          ('washington', 'in'): 7,
#          ('``', 'in'): 7,
#          ('in', '``'): 7,
#          ('school', 'the'): 7,
#          ('chairman', 'of'): 7,
#          ('of', 'chairman'): 7,
#          (',', 'we'): 7,
#          ('have', 'we'): 7,
#          ('have', 'a'): 7,
#          (',', 'both'): 7,
#          ('both', ','): 7,
#          ('he', 'had'): 7,
#          ('that', 'they'): 7,
#          ('they', 'that'): 7,
#          ('the', 'the'): 7,
#          ('is', 'it'): 7,
#          ('said', 'would'): 7,
#          ('since', 'the'): 7,
#          ('the', 'since'): 7,
#          ('the', 'day'): 7,
#          ('which', 'would'): 7,
#          ('would', 'which'): 7,
#          ('of', 'was'): 7,
#          ('it', "''"): 7,
#          ('three', 'the'): 7,
#          ('of', 'by'): 7,
#          ('by', 'of'): 7,
#          ('such', 'as'): 7,
#          ('as', 'such'): 7,
#          ('be', 'on'): 7,
#          ('on', 'be'): 7,
#          ('the', 'public'): 7,
#          ('not', 'to'): 7,
#          ('the', 'present'): 7,
#          ('and', 'was'): 7,
#          ('was', 'and'): 7,
#          ('was', 'in'): 7,
#          ('called', 'for'): 7,
#          ('the', 'program'): 7,
#          ('program', 'the'): 7,
#          ('called', 'the'): 7,
#          (',', 'martin'): 7,
#          (',', 'president'): 7,
#          ('must', 'we'): 7,
#          ('the', 'made'): 7,
#          (',', 'm.'): 7,
#          ('been', ','): 7,
#          (',', 'been'): 7,
#          ('security', 'social'): 7,
#          ('grants', 'to'): 7,
#          ('to', 'grants'): 7,
#          ('year', 'last'): 7,
#          ('of', 'general'): 7,
#          ('general', 'of'): 7,
#          ('program', 'a'): 7,
#          ('the', 'federal'): 7,
#          ('federal', 'the'): 7,
#          ('a', 'session'): 7,
#          ('session', 'a'): 7,
#          ('that', 'united'): 7,
#          ('united', 'that'): 7,
#          ('secretary', 'the'): 7,
#          ('countries', 'the'): 7,
#          ('the', 'conference'): 7,
#          ('states', ','): 7,
#          (',', 'states'): 7,
#          ('of', 'republican'): 7,
#          ('republican', 'of'): 7,
#          ('military', 'the'): 7,
#          ('mr.', 'and'): 7,
#          ('civil', 'defense'): 7,
#          ('defense', 'civil'): 7,
#          ('city', 'and'): 7,
#          ('and', 'city'): 7,
#          ('home', 'rule'): 7,
#          ('rule', 'home'): 7,
#          ('members', 'the'): 7,
#          ('hughes', ','): 7,
#          ('to', 'mr.'): 7,
#          ('mr.', 'to'): 7,
#          ('is', 'and'): 7,
#          ('sales', 'tax'): 7,
#          ('tax', 'sales'): 7,
#          ('county', 'fulton'): 6,
#          ('jury', 'said'): 6,
#          ('this', 'of'): 6,
#          ('other', 'of'): 6,
#          ('and', 'county'): 6,
#          ('county', 'and'): 6,
#          ('of', 'cost'): 6,
#          ("''", 'this'): 6,
#          ('may', 'be'): 6,
#          ('of', 'federal'): 6,
#          ('federal', 'of'): 6,
#          ('is', 'this'): 6,
#          ('one', 'is'): 6,
#          ('the', 'fulton'): 6,
#          ('fulton', 'the'): 6,
#          ('to', 'will'): 6,
#          ("''", 'on'): 6,
#          ('also', 'the'): 6,
#          ('which', 'has'): 6,
#          ('has', 'which'): 6,
#          ('of', 'two'): 6,
#          ('two', 'of'): 6,
#          ('that', 'added'): 6,
#          ('for', 'plan'): 6,
#          ('for', 'city'): 6,
#          ('his', 'and'): 6,
#          ('home', 'the'): 6,
#          ('who', 'a'): 6,
#          ('he', 'not'): 6,
#          (',', 'chairman'): 6,
#          ('a', 'meeting'): 6,
#          ('meeting', 'a'): 6,
#          ('state', 'to'): 6,
#          ('there', 'a'): 6,
#          ('was', 'there'): 6,
#          ('make', 'the'): 6,
#          ('the', 'make'): 6,
#          ('--', 'and'): 6,
#          ('and', '--'): 6,
#          ('the', 'candidates'): 6,
#          ('must', 'the'): 6,
#          ('a', 'which'): 6,
#          ('which', 'a'): 6,
#          ('its', '.'): 6,
#          ('for', 'work'): 6,
#          (',', 'senate'): 6,
#          ('senate', ','): 6,
#          ('study', 'the'): 6,
#          ('the', 'study'): 6,
#          ('issue', 'the'): 6,
#          ('there', 'is'): 6,
#          ('is', 'there'): 6,
#          ('a', 'plan'): 6,
#          ('plan', 'a'): 6,
#          ('to', 'some'): 6,
#          ('battle', 'the'): 6,
#          ('the', 'told'): 6,
#          (',', 'however'): 6,
#          ('will', 'a'): 6,
#          ('in', 'house'): 6,
#          ('house', 'in'): 6,
#          ('day', 'in'): 6,
#          ('in', 'day'): 6,
#          ('resolution', 'the'): 6,
#          ('out', 'that'): 6,
#          ('that', 'out'): 6,
#          ('aid', 'to'): 6,
#          ('the', 'past'): 6,
#          ('who', 'in'): 6,
#          ('in', 'who'): 6,
#          ('into', 'the'): 6,
#          ('the', 'into'): 6,
#          (',', 'be'): 6,
#          ('be', ','): 6,
#          ('of', 'education'): 6,
#          ('a', 'long'): 6,
#          ('long', 'a'): 6,
#          ('a', 'has'): 6,
#          ('a', 'school'): 6,
#          ('school', 'a'): 6,
#          ('school', ','): 6,
#          ('superintendent', ','): 6,
#          (',', 'school'): 6,
#          (',', 'superintendent'): 6,
#          ('was', '``'): 6,
#          ('the', 'he'): 6,
#          ('the', 'before'): 6,
#          ('on', 'committee'): 6,
#          ('on', 'and'): 6,
#          ('and', 'on'): 6,
#          ('for', 'one'): 6,
#          ('one', 'for'): 6,
#          ('million', 'dollars'): 6,
#          ('dollars', 'million'): 6,
#          ('to', 'such'): 6,
#          ('such', 'to'): 6,
#          ('it', 'is'): 6,
#          ('with', 'and'): 6,
#          ('and', 'with'): 6,
#          ('last', '.'): 6,
#          ('more', ','): 6,
#          (',', 'more'): 6,
#          (')', '('): 6,
#          ('to', 'he'): 6,
#          ('to', 'willing'): 6,
#          ('the', 'three'): 6,
#          ('in', 'years'): 6,
#          (',', 'from'): 6,
#          ('need', 'for'): 6,
#          ('for', 'need'): 6,
#          ('house', ','): 6,
#          (',', 'house'): 6,
#          (',', 'attorney'): 6,
#          ('texas', ','): 6,
#          ('that', 'had'): 6,
#          ('had', 'that'): 6,
#          ('jones', ','): 6,
#          (',', 'jones'): 6,
#          ('have', 'the'): 6,
#          ('the', 'have'): 6,
#          ('from', 'a'): 6,
#          ('a', 'from'): 6,
#          ('for', 'was'): 6,
#          ('president', ','): 6,
#          ('must', '``'): 6,
#          (',', 'are'): 6,
#          ('are', ','): 6,
#          ('the', 'two'): 6,
#          ('their', ','): 6,
#          (',', 'their'): 6,
#          ("''", '?'): 6,
#          ('he', 'will'): 6,
#          ('will', 'he'): 6,
#          ('the', 'address'): 6,
#          ('address', 'the'): 6,
#          ('secretary', ','): 6,
#          (',', 'secretary'): 6,
#          ('president', 'kennedy'): 6,
#          ('administration', 'to'): 6,
#          ('to', 'administration'): 6,
#          ('to', 'meet'): 6,
#          ('meet', 'to'): 6,
#          ('m.', ','): 6,
#          ('by', 'and'): 6,
#          ('and', 'by'): 6,
#          ('had', 'the'): 6,
#          ('the', 'if'): 6,
#          ('social', 'security'): 6,
#          ('new', 'and'): 6,
#          ('and', 'new'): 6,
#          ('care', 'the'): 6,
#          ('be', 'it'): 6,
#          ('for', 'each'): 6,
#          ('each', 'for'): 6,
#          ('the', 'kennedy'): 6,
#          ('kennedy', 'the'): 6,
#          ('those', 'who'): 6,
#          ('who', 'those'): 6,
#          ('part', 'the'): 6,
#          ('the', 'part'): 6,
#          ('not', 'a'): 6,
#          ('a', 'not'): 6,
#          ('not', 'does'): 6,
#          ('to', 'build'): 6,
#          ('build', 'to'): 6,
#          ('said', 'president'): 6,
#          ('case', 'in'): 6,
#          ('of', 'its'): 6,
#          ('its', 'of'): 6,
#          ('be', 'more'): 6,
#          ('more', 'be'): 6,
#          ('the', 'track'): 6,
#          (',', 'united'): 6,
#          ('administration', 'in'): 6,
#          ('in', 'administration'): 6,
#          ('the', 'secretary'): 6,
#          ('within', 'the'): 6,
#          ('the', 'within'): 6,
#          ('administration', 'kennedy'): 6,
#          ('communists', 'the'): 6,
#          ('in', 'military'): 6,
#          ('military', 'in'): 6,
#          ('in', 'laos'): 6,
#          ('the', 'world'): 6,
#          ('been', 'in'): 6,
#          ('in', 'been'): 6,
#          ('not', 'be'): 6,
#          ('be', 'not'): 6,
#          ('the', 'military'): 6,
#          ('a', 'had'): 6,
#          (',', 'administration'): 6,
#          ('he', 'has'): 6,
#          ('has', 'he'): 6,
#          (',', 'hawksley'): 6,
#          ('said', 'hawksley'): 6,
#          ('take', 'the'): 6,
#          ('the', 'take'): 6,
#          (',', 'city'): 6,
#          ('the', 'should'): 6,
#          ('should', 'the'): 6,
#          ('last', 'night'): 6,
#          ('of', 'thousands'): 6,
#          ('the', 'hotel'): 6,
#          ('for', 'on'): 6,
#          ('on', 'for'): 6,
#          ('the', 'group'): 6,
#          ('group', 'the'): 6,
#          (',', 'democratic'): 6,
#          ('the', 'man'): 6,
#          ('man', 'the'): 6,
#          ('new', 'jersey'): 6,
#          ('jersey', 'new'): 6,
#          ('same', 'the'): 6,
#          ('democratic', 'party'): 6,
#          ('party', 'democratic'): 6,
#          ('the', 'company'): 6,
#          ('special', 'session'): 6,
#          ('tax', 'bill'): 6,
#          ('the', 'hughes'): 6,
#          ('hughes', 'the'): 6,
#          ('of', 'god'): 6,
#          ('jury', 'grand'): 5,
#          (',', 'committee'): 5,
#          (',', 'had'): 5,
#          ('had', ','): 5,
#          ("''", 'for'): 5,
#          ('was', '.'): 5,
#          ('in', "''"): 5,
#          ('in', 'election'): 5,
#          ('election', 'in'): 5,
#          ('the', 'voters'): 5,
#          ('have', '``'): 5,
#          ('fulton', 'county'): 5,
#          ('cost', 'the'): 5,
#          ('cost', 'of'): 5,
#          ('of', 'administration'): 5,
#          ('department', ','): 5,
#          (',', 'department'): 5,
#          ('``', 'is'): 5,
#          ('take', '``'): 5,
#          ('so', 'that'): 5,
#          ('that', 'so'): 5,
#          ('the', 'may'): 5,
#          ('law', 'the'): 5,
#          ('may', 'the'): 5,
#          ('major', 'in'): 5,
#          ('in', 'major'): 5,
#          ('program', ','): 5,
#          (',', 'program'): 5,
#          ('state', 'department'): 5,
#          ('department', 'state'): 5,
#          ('through', 'the'): 5,
#          ('the', 'through'): 5,
#          ('of', 'county'): 5,
#          ('county', 'of'): 5,
#          ('county', ','): 5,
#          (',', 'county'): 5,
#          ('these', 'of'): 5,
#          ('in', 'program'): 5,
#          ('``', 'we'): 5,
#          ('we', '``'): 5,
#          ('in', 'future'): 5,
#          ('future', 'in'): 5,
#          ('will', 'to'): 5,
#          ('the', 'court'): 5,
#          ('added', 'that'): 5,
#          ('``', 'with'): 5,
#          ('with', '``'): 5,
#          ('to', 'pass'): 5,
#          ('pass', 'to'): 5,
#          ('the', 'office'): 5,
#          (',', 'jr.'): 5,
#          (',', 'j.'): 5,
#          ('j.', ','): 5,
#          ('and', 'his'): 5,
#          ('his', "''"): 5,
#          ('for', 'more'): 5,
#          ('more', 'for'): 5,
#          ('more', 'a'): 5,
#          ('a', 'more'): 5,
#          ('to', 'council'): 5,
#          ('council', 'to'): 5,
#          ('present', 'of'): 5,
#          ('be', 'he'): 5,
#          ('candidate', 'the'): 5,
#          ('the', 'candidate'): 5,
#          ('chairman', ','): 5,
#          ('said', 'a'): 5,
#          ('a', 'said'): 5,
#          ('up', 'for'): 5,
#          ('for', 'up'): 5,
#          ('there', 'was'): 5,
#          ('a', 'vote'): 5,
#          ('vote', 'a'): 5,
#          ('to', 'vote'): 5,
#          ('to', 'one'): 5,
#          ('one', 'to'): 5,
#          ('be', 'taken'): 5,
#          ('taken', 'be'): 5,
#          ('candidates', 'the'): 5,
#          ...})

# %% [markdown]
# ### Weighting function
#
# GloVe includes a weighting function to scale down too frequent words.
#
# <img src = "../figures/glove_weighting_func.png" width=400>

# %%
def weighting(w_i, w_j, X_ik):
    
    #check whether the co-occurences between w_i and w_j is available
    try:
        x_ij = X_ik[(w_i, w_j)]
        #if not exist, then set to 1 "laplace smoothing"
    except:
        x_ij = 1
        
    #set xmax
    x_max = 100
    #set alpha
    alpha = 0.75
    
    #if co-ocurrence does not exceeed xmax, then just multiply with some alpha
    if x_ij < x_max:
        result = (x_ij / x_max)**alpha
    #otherwise, set to 1
    else:
        result = 1
    
    return result

# %%
X_ik = {} #keeping the co-occurences
weighting_dic = {} #already scale the co-occurences using the weighting function

for bigram in combinations_with_replacement(vocabs, 2):
    if X_ik_skipgrams.get(bigram):  #if the pair exists in our corpus
        co = X_ik_skipgrams[bigram]
        X_ik[bigram] = co + 1 #for stability
        X_ik[(bigram[1], bigram[0])] = co + 1 #basically apple, banana = banana, apple
    else:
        pass
    
    weighting_dic[bigram] = weighting(bigram[0], bigram[1], X_ik)
    weighting_dic[(bigram[1], bigram[0])] = weighting(bigram[1], bigram[0], X_ik)

# %% [markdown]
# ## 3. Prepare train data

# %%
def random_batch(batch_size, word_sequence, skip_grams, X_ik, weighting_dic):
    
    random_inputs, random_labels, random_coocs, random_weightings = [], [], [], []
    
    #convert our skipgrams to id
    skip_grams_id = [(word2index[skip_gram[0]], word2index[skip_gram[1]]) for skip_gram in skip_grams]
    
    #randomly choose indexes based on batch size
    random_index = np.random.choice(range(len(skip_grams_id)), batch_size, replace=False)
    
    #get the random input and labels
    for index in random_index:
        random_inputs.append([skip_grams_id[index][0]])
        random_labels.append([skip_grams_id[index][1]])
        #coocs
        pair = skip_grams[index] #e.g., ('banana', 'fruit')
        try:
            cooc = X_ik[pair]
        except:
            cooc = 1
        random_coocs.append([math.log(cooc)])
    
        #weightings
        weighting = weighting_dic[pair]
        random_weightings.append([weighting])
        
    return np.array(random_inputs), np.array(random_labels), np.array(random_coocs), np.array(random_weightings)

# %% [markdown]
# ## 4. Model
#
# <img src ="../figures/glove.png" width=400>

# %%
class Glove(nn.Module):
    
    def __init__(self, voc_size, emb_size):
        super(Glove, self).__init__()
        self.embedding_center  = nn.Embedding(voc_size, emb_size)
        self.embedding_outside = nn.Embedding(voc_size, emb_size)
        
        self.center_bias       = nn.Embedding(voc_size, 1) 
        self.outside_bias      = nn.Embedding(voc_size, 1)
    
    def forward(self, center, outside, coocs, weighting):
        center_embeds  = self.embedding_center(center) #(batch_size, 1, emb_size)
        outside_embeds = self.embedding_outside(outside) #(batch_size, 1, emb_size)
        
        center_bias    = self.center_bias(center).squeeze(1)
        target_bias    = self.outside_bias(outside).squeeze(1)
        
        inner_product  = outside_embeds.bmm(center_embeds.transpose(1, 2)).squeeze(2)
        #(batch_size, 1, emb_size) @ (batch_size, emb_size, 1) = (batch_size, 1, 1) = (batch_size, 1)
        
        loss = weighting * torch.pow(inner_product + center_bias + target_bias - coocs, 2)
        
        return torch.sum(loss)

# %% [markdown]
# ## 5. Training

# %%
batch_size     = 10 # mini-batch size
embedding_size = 2 #so we can later plot
glove_model = Glove(voc_size, embedding_size).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(glove_model.parameters(), lr=0.001)

# %%
# Training
# epochs = 10000 #todo
epochs = 10
start_time = time.time()

for epoch in range(epochs):    
    input_batch, target_batch, cooc_batch, weighting_batch = random_batch(batch_size, news_corpus, skip_grams, X_ik, weighting_dic)
    input_batch  = torch.LongTensor(input_batch).to(device)         #[batch_size, 1]
    target_batch = torch.LongTensor(target_batch).to(device)        #[batch_size, 1]
    cooc_batch   = torch.FloatTensor(cooc_batch).to(device)         #[batch_size, 1]
    weighting_batch = torch.FloatTensor(weighting_batch).to(device) #[batch_size, 1]
    
    optimizer.zero_grad()
    loss = glove_model(input_batch, target_batch, cooc_batch, weighting_batch)
    
    loss.backward()
    optimizer.step()
    
    end = time.time()

    # if (epoch + 1) % 1000 == 0: todo
    print(f"Epoch: {epoch + 1} | cost: {loss:.6f}")
    
print(f"Training time: {time.time()-start_time}")
# Out:
# Epoch: 1 | cost: 16.266325
# Epoch: 2 | cost: 4.335627
# Epoch: 3 | cost: 1.148447
# Epoch: 4 | cost: 1.776109
# Epoch: 5 | cost: 5.049794
# Epoch: 6 | cost: 66.619392
# Epoch: 7 | cost: 21.762074
# Epoch: 8 | cost: 6.029619
# Epoch: 9 | cost: 1.802944
# Epoch: 10 | cost: 10.500910
# Training time: 0.15765905380249023

# %% [markdown]
# ## GloVe (Gensim)
#
# For looking at word vectors, we'll use **Gensim**. **Gensim** isn't really a deep learning package. It's a package for for word and text similarity modeling, which started with (LDA-style) topic models and grew into SVD and neural word representations. But its efficient and scalable, and quite widely used.   We gonna use **GloVe** embeddings, downloaded at [the Glove page](https://nlp.stanford.edu/projects/glove/). They're inside [this zip file](https://nlp.stanford.edu/data/glove.6B.zip)

# %%
glove_file = datapath(os.path.abspath('glove.6B.100d.txt'))  #search on the google
gensim_model = KeyedVectors.load_word2vec_format(glove_file, binary=False, no_header=True)

# %%
#return the vectors
gensim_model['coffee'].shape
# Out:
# (100,)

# %%
# caculating embeddings
def calculate_word_embedding(model, vocabulary):
    word_embedding = {}

    for term in vocabulary:
        try:
            term_index = word2index[term]
        except KeyError:
            term_index = word2index['<UNK>']

        input_index = torch.LongTensor([word2index[term]])

        vector_center = model.embedding_center(input_index)
        vector_outside = model.embedding_outside(input_index)
        final_vector = (vector_center + vector_outside) / 2
        final_vector = final_vector[0][0].item(), final_vector[0][1].item()
        word_embedding[term] = np.array(final_vector)

    return word_embedding

# %%
def fetch_vector(embedding_dict, term):
    try:
        term_index = word2index[term]
    except KeyError:
        term = '<UNK>'

    return embedding_dict[term]

# %%
# Compute word embedding for each model
skipgram = calculate_word_embedding(skipgram_model, vocabs)
skipgram_negative = calculate_word_embedding(skipgram_neg_model, vocabs)
glove = calculate_word_embedding(glove_model, vocabs)
vector_storage = {"skipgram": skipgram, "skipgram_negative": skipgram_negative, "glove": glove}

# %%
# Save the computed embedding to pickles
for vector_set in vector_storage.items():
    with open(f"{vector_set[0]}.pkl", "wb") as file:
        pickle.dump(vector_set[1], file)

# %%
# Fetch a specific word embedding
fetch_vector(skipgram_negative, 'berlin')
# Out:
# array([0.34038132, 0.08317519])

# %%
# Load analogy dataset
with open("word-test.v1.txt", "r") as file:
    dataset_content = file.read()

# %%
# Preprocess the dataset
formatted_data = dataset_content.replace("\t", "")
data_sections = formatted_data.split(': ')

# %%
# Extract "capital-common-countries" section
capital_pairs = data_sections[1].split('\n')[1:-1]
capital_pairs = [pair.split(" ") for pair in capital_pairs]

# %%
# Extract "gram7-past-tense" section
past_tense_pairs = data_sections[12].split('\n')[1:-1]
past_tense_pairs = [pair.split(" ") for pair in past_tense_pairs]

# %%
# cosine similarity
def cosine_similarity(vec1, vec2):
    dot = np.dot(vec1, vec2)
    norm1 = np.linalg.norm(vec1)
    norm2 = np.linalg.norm(vec2)
    return dot / (norm1 * norm2)

# %%
# Identify the closest word to a given vector
def closest_match(vector, embeddings):
    try:
        words_in_vocab = list(embeddings.keys())
    except:
        words_in_vocab = list(embeddings.key_to_index.keys())

    similarity_scores = {}

    for word in words_in_vocab:
        similarity_scores[word] = cosine_similarity(vector, embeddings[word])

    return max(similarity_scores, key=similarity_scores.get)

# %%
# Rank similarities for a vector
def rank_by_similarity(vector, embeddings):
    try:
        word_keys = list(embeddings.keys())
    except:
        word_keys = list(embeddings.key_to_index.keys())

    similarity_scores = {}

    for word in word_keys:
        similarity_scores[word] = cosine_similarity(vector, embeddings[word])

    return dict(sorted(similarity_scores.items(), key=lambda item: item[1], reverse=True))

# %%
# Calculate accuracy for analogy tasks
def calculate_accuracy(pairs, embeddings):
    matches = 0

    for example in pairs:
        example = [term.lower() for term in example]

        try:
            predicted_vector = fetch_vector(embeddings, example[1]) - fetch_vector(embeddings, example[0]) + fetch_vector(embeddings, example[2])
            predicted_word = closest_match(predicted_vector, embeddings)
        except KeyError:
            predicted_word = embeddings.most_similar(positive=[example[1], example[2]], negative=[example[0]])[0][0]

        if example[3] == predicted_word:
            matches += 1

    return matches / len(pairs)

# %%
# # tesing
# skipgram_sem_acc = calculate_accuracy(capital_pairs, skipgram)
# skipgram_syn_acc = calculate_accuracy(past_tense_pairs, skipgram)

# neg_sem_acc = calculate_accuracy(capital_pairs, skipgram_negative)
# neg_syn_acc = calculate_accuracy(past_tense_pairs, skipgram_negative)

# glove_sem_acc = calculate_accuracy(capital_pairs, glove)
# glove_syn_acc = calculate_accuracy(past_tense_pairs, glove)

# glove_gensim_sem_acc = calculate_accuracy(capital_pairs, gensim_model)
# glove_gensim_syn_acc = calculate_accuracy(past_tense_pairs, gensim_model)

# # Display results
# print("Word2Vec skipgram accuracy")
# print(f"Semantic: {skipgram_sem_acc}")
# print(f"Syntactic: {skipgram_syn_acc}\n")

# print("Word2Vec negative accuracy")
# print(f"Semantic: {neg_sem_acc}")
# print(f"Syntactic: {neg_syn_acc}\n")

# print("GloVe accuracy")
# print(f"Semantic: {glove_sem_acc}")
# print(f"Syntactic: {glove_syn_acc}\n")

# print("GloVe gensim accuracy")
# print(f"Semantic: {glove_gensim_sem_acc}")
# print(f"Syntactic: {glove_gensim_syn_acc}\n")

# %% [markdown]
# ### I initially selected the "news" category from the NLTK dataset to categorize news articles. However, I encountered an issue where the model's accuracy was 0, likely due to the data or the model's approach. As a result, I decided to switch to using the Brown corpus by utilizing brown.sents(categories='news') for better results.

# %%
# tesing
skipgram_sem_acc = calculate_accuracy(capital_pairs, skipgram)
skipgram_syn_acc = calculate_accuracy(past_tense_pairs, skipgram)

neg_sem_acc = calculate_accuracy(capital_pairs, skipgram_negative)
neg_syn_acc = calculate_accuracy(past_tense_pairs, skipgram_negative)

glove_sem_acc = calculate_accuracy(capital_pairs, glove)
glove_syn_acc = calculate_accuracy(past_tense_pairs, glove)

glove_gensim_sem_acc = calculate_accuracy(capital_pairs, gensim_model)
glove_gensim_syn_acc = calculate_accuracy(past_tense_pairs, gensim_model)

# Display results
print("Word2Vec skipgram accuracy")
print(f"Semantic: {skipgram_sem_acc}")
print(f"Syntactic: {skipgram_syn_acc}\n")

print("Word2Vec negative accuracy")
print(f"Semantic: {neg_sem_acc}")
print(f"Syntactic: {neg_syn_acc}\n")

print("GloVe accuracy")
print(f"Semantic: {glove_sem_acc}")
print(f"Syntactic: {glove_syn_acc}\n")

print("GloVe gensim accuracy")
print(f"Semantic: {glove_gensim_sem_acc}")
print(f"Syntactic: {glove_gensim_syn_acc}\n")
# Out:
# Word2Vec skipgram accuracy
# Semantic: 0.0
# Syntactic: 0.0
#
# Word2Vec negative accuracy
# Semantic: 0.0
# Syntactic: 0.0
#
# GloVe accuracy
# Semantic: 0.0
# Syntactic: 0.0
#
# GloVe gensim accuracy
# Semantic: 0.5064102564102564
# Syntactic: 0.5064102564102564

# %%
print(f"Semantic: {glove_gensim_sem_acc}")
# Out:
# Semantic: 0.9387351778656127

# %%
# load similarity dataset for similarity correlation
similar_words = pd.read_csv('wordsim_similarity_goldstandard.txt', sep="\t", header=None, names=['word_1', 'word_2', 'similarities'])
similar_words
# Out:
#          word_1    word_2  similarities
# 0         tiger       cat          7.35
# 1         tiger     tiger         10.00
# 2         plane       car          5.77
# 3         train       car          6.31
# 4    television     radio          6.77
# ..          ...       ...           ...
# 198     rooster    voyage          0.62
# 199        noon    string          0.54
# 200       chord     smile          0.54
# 201   professor  cucumber          0.31
# 202        king   cabbage          0.23
#
# [203 rows x 3 columns]

# %%
# Creating a method to compute dot products between word embeddings for different models
def compute_dot_product(model, word1, word2):
    word1_vec = fetch_vector(model, word1.lower())
    word2_vec = fetch_vector(model, word2.lower())
    return np.dot(word1_vec, word2_vec)

# %%
# Applying the method to calculate dot products between word embeddings
similar_words['skipgram'] = similar_words.apply(lambda row: compute_dot_product(skipgram, row['word_1'], row['word_2']), axis=1)
similar_words['skipgram_negative_sampling'] = similar_words.apply(lambda row: compute_dot_product(skipgram_negative, row['word_1'], row['word_2']), axis=1)
similar_words['glove'] = similar_words.apply(lambda row: compute_dot_product(glove, row['word_1'], row['word_2']), axis=1)
similar_words['glove_gensim'] = similar_words.apply(lambda row: np.dot(gensim_model[row['word_1'].lower()], gensim_model[row['word_2'].lower()]), axis=1)

# %%
# Extracting similarity scores and model-specific dot products
wordsim_scores = similar_words['similarities'].to_numpy()
skipgram_scores = similar_words['skipgram'].to_numpy()
negative_sampling_scores = similar_words['skipgram_negative_sampling'].to_numpy()
glove_scores = similar_words['glove'].to_numpy()
gensim_scores = similar_words['glove_gensim'].to_numpy()

# %%
# correlations
print(f"Skipgram: {spearmanr(wordsim_scores, skipgram_scores).statistic}")
print(f"Skipgram Negative: {spearmanr(wordsim_scores, negative_sampling_scores).statistic}")
print(f"GloVe: {spearmanr(wordsim_scores, glove_scores).statistic}")
print(f"GloVe gensim: {spearmanr(wordsim_scores, gensim_scores).statistic}")
# Out:
# Skipgram: 0.06420451879921557
# Skipgram Negative: -0.059984396233358724
# GloVe: 0.05199217528883568
# GloVe gensim: 0.5430870624672256
